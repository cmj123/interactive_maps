# %%
import folium
import pandas as pd

# %%
df_suburbs = pd.read_excel("waterwatch_clean2.xlsx", index_col=[0], sheet_name='Sheet1')
df_suburbs.head()
# Out:
#             Suburb  Number of single-residential properties_number  \
# 0          ATHLONE                                            2272
# 1           AURORA                                             426
# 2       BANTRY BAY                                             248
# 3  BELLVILLE SOUTH                                            2041
# 4        BERGVLIET                                            1488
#
#    Oct 2017\nkl/month    Month  Year   Latitude  Longitude
# 0                  11  October  2017 -33.967220  18.502140
# 1                  10  October  2017 -32.705958  18.485135
# 2                  13  October  2017 -33.927953  18.382592
# 3                  11  October  2017 -33.920011  18.642819
# 4                   8  October  2017 -34.047464  18.452499

# %%
# Create a base map
map_osm = folium.Map(location=[-33.967220,18.502140], zoom_start=10)

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de22a0cf5e421be26ce86357f1374252 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de22a0cf5e421be26ce86357f1374252&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de22a0cf5e421be26ce86357f1374252 = L.map(
#                 &quot;map_de22a0cf5e421be26ce86357f1374252&quot;,
#                 {
#                     center: [-33.96722, 18.50214],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbb041965f55d5cdbfc6235b8056a8a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a base map with tiles
map_dark = folium.Map(location=[-34.047464, 18.452499], tiles='CartoDB dark_matter', zoom_start=10)
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8162b68971149a3318af5e36d210eac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8162b68971149a3318af5e36d210eac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8162b68971149a3318af5e36d210eac4 = L.map(
#                 &quot;map_8162b68971149a3318af5e36d210eac4&quot;,
#                 {
#                     center: [-34.047464, 18.452499],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9524a383a33c88c4fd02929db3d5d4c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Get the length of the dateset
df_suburbs_locations = df_suburbs[['Latitude', 'Longitude']]
suburbs_location_list = df_suburbs_locations.values.tolist()
suburbs_location_list_size = len(suburbs_location_list)
suburbs_location_list_size
# Out:
# 121

# %%
# Plot point of graph
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point]).add_to(map_osm)
    folium.Marker(suburbs_location_list[point]).add_to(map_dark)
    
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de22a0cf5e421be26ce86357f1374252 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de22a0cf5e421be26ce86357f1374252&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de22a0cf5e421be26ce86357f1374252 = L.map(
#                 &quot;map_de22a0cf5e421be26ce86357f1374252&quot;,
#                 {
#                     center: [-33.96722, 18.50214],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbb041965f55d5cdbfc6235b8056a8a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_b6fd4fc85c3175c79948abd4e5a5aedd = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_87b040e40abe75b8ac9dae96791aeee0 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_3e6bd67227f83873dae43bc874e7947d = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_f1be4735ee8fdc44b6e96b60d1dfba60 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_18d36b0b0afe6af2039b73c417f5c4e6 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_ac66d769e1d06d254140497e6578df8c = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_3564a96a3e089667d8d533d99f209bd4 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_2474a97757a392a38cad760c9e0ed2a0 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_46877f7778d927d5ffe47a773465bcff = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_9a42490440263fa52317fdb70d83fbee = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_7d91dd2bbf66d8304ade93c4f7b6df99 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_0f11cb129031141b5fe928de9b3c1472 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_271a4eb5452fb0a686ef02c607c34737 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_2210d42ccf9711afff034930abd6b14b = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_bb0f5573268ef54aad9206bb0bd8e97d = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_fea1cb1042c075bf7debb977810ec428 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_aee9f690a88c6947a9e755f40af68769 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_4c1dd3320ee53c3a6842e93e3a09f256 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_7d0856da06efad9b303eb86040a2a031 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_5e2c0316640153c432438dc36f8d9cba = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_e8065e3a03c123b163c9dbd4b00bb975 = L.marker(
#                 [-33.841588, 18.651795],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8162b68971149a3318af5e36d210eac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8162b68971149a3318af5e36d210eac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8162b68971149a3318af5e36d210eac4 = L.map(
#                 &quot;map_8162b68971149a3318af5e36d210eac4&quot;,
#                 {
#                     center: [-34.047464, 18.452499],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9524a383a33c88c4fd02929db3d5d4c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_3ae796b8e93c597284e588b08358eb89 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_90c7335962dc7e48b5502b514a8e1a33 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_df1851d4f5e88b34b5fb8c7006a41d2e = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_97e34b949f3dbd5cf2c42a02d98fac4f = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_4e86c1dc7157a8d0955bd1fe05a6207d = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_06bd778f2d21f8fe3508771c65d57de6 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_72eae0eaabb524b57db558cbb13da159 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_559cfd44012e08afc07c48986d03594c = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_af90a4fe6870ed2f1bfbd795a505b5b0 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_89da36368bff2f6f82842ca427f53068 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_32e4bffa2986ea6b493c8c438d78346d = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_7cf040dd638fef0c51074cfba9447eb1 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_34d4131573c6c697d4230e15c9e821e4 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_82173e8a1305c852c1321ac7f2faa70e = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_2a39858988b6e720c659daf7bb8f7c70 = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_cac55b691347d89e78047499e8da66d4 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_80d94610db403ab384109b78f7709ed6 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_976054976c4f716243cbd6ed4bf4e258 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_5b8d4e14d6647b5fd9dc4cda5df93a92 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_94b4e4ab118d20a80c9d822654deaa19 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_c506a5eb8e730467e672e27b3445

# %%
# Adding popups messgae
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point]).add_to(map_osm)
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point]).add_to(map_dark)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de22a0cf5e421be26ce86357f1374252 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de22a0cf5e421be26ce86357f1374252&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de22a0cf5e421be26ce86357f1374252 = L.map(
#                 &quot;map_de22a0cf5e421be26ce86357f1374252&quot;,
#                 {
#                     center: [-33.96722, 18.50214],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbb041965f55d5cdbfc6235b8056a8a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_b6fd4fc85c3175c79948abd4e5a5aedd = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_87b040e40abe75b8ac9dae96791aeee0 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_3e6bd67227f83873dae43bc874e7947d = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_f1be4735ee8fdc44b6e96b60d1dfba60 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_18d36b0b0afe6af2039b73c417f5c4e6 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_ac66d769e1d06d254140497e6578df8c = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_3564a96a3e089667d8d533d99f209bd4 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_2474a97757a392a38cad760c9e0ed2a0 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_46877f7778d927d5ffe47a773465bcff = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_9a42490440263fa52317fdb70d83fbee = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_7d91dd2bbf66d8304ade93c4f7b6df99 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_0f11cb129031141b5fe928de9b3c1472 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_271a4eb5452fb0a686ef02c607c34737 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_2210d42ccf9711afff034930abd6b14b = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_bb0f5573268ef54aad9206bb0bd8e97d = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_fea1cb1042c075bf7debb977810ec428 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_aee9f690a88c6947a9e755f40af68769 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_4c1dd3320ee53c3a6842e93e3a09f256 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_7d0856da06efad9b303eb86040a2a031 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_5e2c0316640153c432438dc36f8d9cba = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_e8065e3a03c123b163c9dbd4b00bb975 = L.marker(
#                 [-33.841588, 18.651795],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8162b68971149a3318af5e36d210eac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8162b68971149a3318af5e36d210eac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8162b68971149a3318af5e36d210eac4 = L.map(
#                 &quot;map_8162b68971149a3318af5e36d210eac4&quot;,
#                 {
#                     center: [-34.047464, 18.452499],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9524a383a33c88c4fd02929db3d5d4c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_3ae796b8e93c597284e588b08358eb89 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_90c7335962dc7e48b5502b514a8e1a33 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_df1851d4f5e88b34b5fb8c7006a41d2e = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_97e34b949f3dbd5cf2c42a02d98fac4f = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_4e86c1dc7157a8d0955bd1fe05a6207d = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_06bd778f2d21f8fe3508771c65d57de6 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_72eae0eaabb524b57db558cbb13da159 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_559cfd44012e08afc07c48986d03594c = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_af90a4fe6870ed2f1bfbd795a505b5b0 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_89da36368bff2f6f82842ca427f53068 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_32e4bffa2986ea6b493c8c438d78346d = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_7cf040dd638fef0c51074cfba9447eb1 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_34d4131573c6c697d4230e15c9e821e4 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_82173e8a1305c852c1321ac7f2faa70e = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_2a39858988b6e720c659daf7bb8f7c70 = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_cac55b691347d89e78047499e8da66d4 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_80d94610db403ab384109b78f7709ed6 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_976054976c4f716243cbd6ed4bf4e258 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_5b8d4e14d6647b5fd9dc4cda5df93a92 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_94b4e4ab118d20a80c9d822654deaa19 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_c506a5eb8e730467e672e27b3445

# %%
# Specifying the icon
for point in range(0, suburbs_location_list_size):
#     folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point], icon=folium.Icon(color='darkblue', icon_color='white', icon='tint', angle=180, prefix='fa')).add_to(map_osm)
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point], icon=folium.Icon(color='darkblue', icon_color='white', icon='tint', angle=180, prefix='fa fa-plus')).add_to(map_dark)
    
# map_osm

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8162b68971149a3318af5e36d210eac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8162b68971149a3318af5e36d210eac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8162b68971149a3318af5e36d210eac4 = L.map(
#                 &quot;map_8162b68971149a3318af5e36d210eac4&quot;,
#                 {
#                     center: [-34.047464, 18.452499],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9524a383a33c88c4fd02929db3d5d4c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_3ae796b8e93c597284e588b08358eb89 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_90c7335962dc7e48b5502b514a8e1a33 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_df1851d4f5e88b34b5fb8c7006a41d2e = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_97e34b949f3dbd5cf2c42a02d98fac4f = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_4e86c1dc7157a8d0955bd1fe05a6207d = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_06bd778f2d21f8fe3508771c65d57de6 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_72eae0eaabb524b57db558cbb13da159 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_559cfd44012e08afc07c48986d03594c = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_af90a4fe6870ed2f1bfbd795a505b5b0 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_89da36368bff2f6f82842ca427f53068 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_32e4bffa2986ea6b493c8c438d78346d = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_7cf040dd638fef0c51074cfba9447eb1 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_34d4131573c6c697d4230e15c9e821e4 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_82173e8a1305c852c1321ac7f2faa70e = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_2a39858988b6e720c659daf7bb8f7c70 = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_cac55b691347d89e78047499e8da66d4 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_80d94610db403ab384109b78f7709ed6 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_976054976c4f716243cbd6ed4bf4e258 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_5b8d4e14d6647b5fd9dc4cda5df93a92 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_94b4e4ab118d20a80c9d822654deaa19 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_c506a5eb8e730467e672e27b3445

# %%
# Classification
for point in range(0, suburbs_location_list_size):
    if df_suburbs['Oct 2017\nkl/month'][point] <= 5:
        folium.Marker(
            suburbs_location_list[point],
            popup=df_suburbs['Suburb'][point],
            icon=folium.Icon(color='green', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')
        ).add_to(map_osm)
        folium.Marker(
            suburbs_location_list[point],
            popup=df_suburbs['Suburb'][point],
            icon=folium.Icon(color='green', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')
        ).add_to(map_dark)
    
    elif df_suburbs['Oct 2017\nkl/month'][point] > 5 and df_suburbs['Oct 2017\nkl/month'][point] <= 8:
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='blue', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_osm)
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='blue', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_dark)
        
    else:
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='red', icon_color='white', icon='thumbs-down', angle=0, prefix='fa')).add_to(map_osm)
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='red', icon_color='white', icon='thumbs-down', angle=0, prefix='fa')).add_to(map_dark)
        

        
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de22a0cf5e421be26ce86357f1374252 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de22a0cf5e421be26ce86357f1374252&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de22a0cf5e421be26ce86357f1374252 = L.map(
#                 &quot;map_de22a0cf5e421be26ce86357f1374252&quot;,
#                 {
#                     center: [-33.96722, 18.50214],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbb041965f55d5cdbfc6235b8056a8a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_b6fd4fc85c3175c79948abd4e5a5aedd = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_87b040e40abe75b8ac9dae96791aeee0 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_3e6bd67227f83873dae43bc874e7947d = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_f1be4735ee8fdc44b6e96b60d1dfba60 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_18d36b0b0afe6af2039b73c417f5c4e6 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_ac66d769e1d06d254140497e6578df8c = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_3564a96a3e089667d8d533d99f209bd4 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_2474a97757a392a38cad760c9e0ed2a0 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_46877f7778d927d5ffe47a773465bcff = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_9a42490440263fa52317fdb70d83fbee = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_7d91dd2bbf66d8304ade93c4f7b6df99 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_0f11cb129031141b5fe928de9b3c1472 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_271a4eb5452fb0a686ef02c607c34737 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_2210d42ccf9711afff034930abd6b14b = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_bb0f5573268ef54aad9206bb0bd8e97d = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_fea1cb1042c075bf7debb977810ec428 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_aee9f690a88c6947a9e755f40af68769 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_4c1dd3320ee53c3a6842e93e3a09f256 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_7d0856da06efad9b303eb86040a2a031 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_5e2c0316640153c432438dc36f8d9cba = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);
#
#
#             var marker_e8065e3a03c123b163c9dbd4b00bb975 = L.marker(
#                 [-33.841588, 18.651795],
#                 {}
#             ).addTo(map_de22a0cf5e421be26ce86357f1374252);

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8162b68971149a3318af5e36d210eac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8162b68971149a3318af5e36d210eac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8162b68971149a3318af5e36d210eac4 = L.map(
#                 &quot;map_8162b68971149a3318af5e36d210eac4&quot;,
#                 {
#                     center: [-34.047464, 18.452499],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9524a383a33c88c4fd02929db3d5d4c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_3ae796b8e93c597284e588b08358eb89 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_90c7335962dc7e48b5502b514a8e1a33 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_df1851d4f5e88b34b5fb8c7006a41d2e = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_97e34b949f3dbd5cf2c42a02d98fac4f = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_4e86c1dc7157a8d0955bd1fe05a6207d = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_06bd778f2d21f8fe3508771c65d57de6 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_72eae0eaabb524b57db558cbb13da159 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_559cfd44012e08afc07c48986d03594c = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_af90a4fe6870ed2f1bfbd795a505b5b0 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_89da36368bff2f6f82842ca427f53068 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_32e4bffa2986ea6b493c8c438d78346d = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_7cf040dd638fef0c51074cfba9447eb1 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_34d4131573c6c697d4230e15c9e821e4 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_82173e8a1305c852c1321ac7f2faa70e = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_2a39858988b6e720c659daf7bb8f7c70 = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_cac55b691347d89e78047499e8da66d4 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_80d94610db403ab384109b78f7709ed6 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_976054976c4f716243cbd6ed4bf4e258 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_5b8d4e14d6647b5fd9dc4cda5df93a92 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_94b4e4ab118d20a80c9d822654deaa19 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_8162b68971149a3318af5e36d210eac4);
#
#
#             var marker_c506a5eb8e730467e672e27b3445

# %%
# Creating a point map
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point]*100),
        color='#17cbef',
        fill=True,
        opacity=0.8,  
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_points)
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce41883fbafde7b39357d4efe24653fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce41883fbafde7b39357d4efe24653fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce41883fbafde7b39357d4efe24653fb = L.map(
#                 &quot;map_ce41883fbafde7b39357d4efe24653fb&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f5b3288022f5b375a215561dceb3f56 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ce41883fbafde7b39357d4efe24653fb);
#
#
#             var circle_26d292623913a41489f4cc7ea9b4cbb1 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_ce41883fbafde7b39357d4efe24653fb);
#
#
#         var popup_09fa4fdc5d845192b96b5bae35a801b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0edf7cc4e82f9e493436bf7cadabe365 = $(`&lt;div id=&quot;html_0edf7cc4e82f9e493436bf7cadabe365&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_09fa4fdc5d845192b96b5bae35a801b5.setContent(html_0edf7cc4e82f9e493436bf7cadabe365);
#
#
#
#         circle_26d292623913a41489f4cc7ea9b4cbb1.bindPopup(popup_09fa4fdc5d845192b96b5bae35a801b5)
#         ;
#
#
#
#
#             var circle_b50eb195d52144e2cc0e9c53401f953f = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_ce41883fbafde7b39357d4efe24653fb);
#
#
#         var popup_7d99a50f7bdec8989a79ee106f05698d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe88c6bc14bb2e3e235ba8400c890878 = $(`&lt;div id=&quot;html_fe88c6bc14bb2e3e235ba8400c890878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_7d99a50f7bdec8989a79ee106f05698d.setContent(html_fe88c6bc14bb2e3e235ba8400c890878);
#
#
#
#         circle_b50eb195d52144e2cc0e9c53401f953f.bindPopup(popup_7d99a50f7bdec8989a79ee106f05698d)
#         ;
#
#
#
#
#             var circle_725246f57e930a4a42145cf9cedcc90a = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_ce41883fbafde7b39357d4efe24653fb);
#
#
#         var popup_ca00a92348f6f92b4dd5065194f24a6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2eaabc96099d9a9e2430218c692c5479 = $(`&lt;div id=&quot;html_2eaabc96099d9a9e2430218c692c5479&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_ca00a92348f6f92b4dd5065194f24a6c.setContent(html_2eaabc96099d9a9e2430218c692c5479);
#
#
#
#         circle_725246f57e930a4a42145cf9cedcc90a.bindPopup(popup_ca00a92348f6f92b4dd5065194f24a6c)
#         ;
#
#
#
#
#             var circle_931948c34086a2db463368a23baf61e6 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &

# %%
# Adding Classification
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    # classify by usage
    if df_suburbs['Oct 2017\nkl/month'][point] <= 8 and df_suburbs['Oct 2017\nkl/month'][point] > 0:
        usage_color = 'green'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 8 and df_suburbs['Oct 2017\nkl/month'][point] <= 10:
        usage_color = '#17cbef'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 10:
        usage_color = 'red'
    else:
        usage_color ='orange'
        
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point]*100),
        color=usage_color,
        fill=True,
        opacity=0.8,  
        fill_color=usage_color,
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24456ff372d4a228a36012284d91d6a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24456ff372d4a228a36012284d91d6a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24456ff372d4a228a36012284d91d6a1 = L.map(
#                 &quot;map_24456ff372d4a228a36012284d91d6a1&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccece05ef6728b38fa5f334b5fe6db96 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24456ff372d4a228a36012284d91d6a1);
#
#
#             var circle_5ee4a12409015fa00219f638c477ca3b = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_24456ff372d4a228a36012284d91d6a1);
#
#
#         var popup_cab80fa9372d84b67baff1a82a02069c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90def6777529dc945b292a006155927e = $(`&lt;div id=&quot;html_90def6777529dc945b292a006155927e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_cab80fa9372d84b67baff1a82a02069c.setContent(html_90def6777529dc945b292a006155927e);
#
#
#
#         circle_5ee4a12409015fa00219f638c477ca3b.bindPopup(popup_cab80fa9372d84b67baff1a82a02069c)
#         ;
#
#
#
#
#             var circle_960b856286ca9d39df86df5a53d94c06 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_24456ff372d4a228a36012284d91d6a1);
#
#
#         var popup_2c1c9a56c88013ac3f4029b9c51027f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33d924cb43186d7b3f56fad525c8b327 = $(`&lt;div id=&quot;html_33d924cb43186d7b3f56fad525c8b327&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_2c1c9a56c88013ac3f4029b9c51027f8.setContent(html_33d924cb43186d7b3f56fad525c8b327);
#
#
#
#         circle_960b856286ca9d39df86df5a53d94c06.bindPopup(popup_2c1c9a56c88013ac3f4029b9c51027f8)
#         ;
#
#
#
#
#             var circle_3df504cc6d6d96e85157b96237eefb25 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_24456ff372d4a228a36012284d91d6a1);
#
#
#         var popup_2c4eea25a813af62c0ac828716292e42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27c9637eb547ba2e01d90719145409f4 = $(`&lt;div id=&quot;html_27c9637eb547ba2e01d90719145409f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_2c4eea25a813af62c0ac828716292e42.setContent(html_27c9637eb547ba2e01d90719145409f4);
#
#
#
#         circle_3df504cc6d6d96e85157b96237eefb25.bindPopup(popup_2c4eea25a813af62c0ac828716292e42)
#         ;
#
#
#
#
#             var circle_91ecf4b0c8248debf56b4c2b61083dd2 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru
