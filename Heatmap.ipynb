# %%
import folium
from folium.plugins import HeatMap
import pandas as pd

# %%
df_suburbs = pd.read_excel('waterwatch_clean2.xlsx', sheet_name='Sheet1')

df_suburbs.head()
# Out:
#    Unnamed: 0           Suburb  \
# 0           0          ATHLONE
# 1           1           AURORA
# 2           2       BANTRY BAY
# 3           3  BELLVILLE SOUTH
# 4           4        BERGVLIET
#
#    Number of single-residential properties_number  Oct 2017\nkl/month  \
# 0                                            2272                  11
# 1                                             426                  10
# 2                                             248                  13
# 3                                            2041                  11
# 4                                            1488                   8
#
#      Month  Year   Latitude  Longitude
# 0  October  2017 -33.967220  18.502140
# 1  October  2017 -32.705958  18.485135
# 2  October  2017 -33.927953  18.382592
# 3  October  2017 -33.920011  18.642819
# 4  October  2017 -34.047464  18.452499

# %%
df_suburbs_locations = df_suburbs[['Latitude', 'Longitude']]
#df_suburbs_locations
suburbs_location_list = df_suburbs_locations.values.tolist()
suburbs_location_list_size = len(suburbs_location_list)
suburbs_location_list_size
# Out:
# 121

# %%
# Creating Heatmap

# Create our point map object
map_heat = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_heat)
    

# convert to array format for our heatmap
suburbsArray = df_suburbs[['Latitude', 'Longitude']].values
# convert to array format for our heatmap
map_heat.add_child(HeatMap(suburbsArray))

map_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d4faae5cc6b58052169011591bc8bf1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d4faae5cc6b58052169011591bc8bf1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d4faae5cc6b58052169011591bc8bf1 = L.map(
#                 &quot;map_7d4faae5cc6b58052169011591bc8bf1&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e51355c2d50da743408d0c2551885255 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d4faae5cc6b58052169011591bc8bf1);
#
#
#             var circle_6245b45857f2dd0a76eefd859b1f46e6 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_7d4faae5cc6b58052169011591bc8bf1);
#
#
#         var popup_f4264b94d371c2184cb154d5b3dcef90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f187b5b9e9c45b6259ba92fe8c60a8f0 = $(`&lt;div id=&quot;html_f187b5b9e9c45b6259ba92fe8c60a8f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_f4264b94d371c2184cb154d5b3dcef90.setContent(html_f187b5b9e9c45b6259ba92fe8c60a8f0);
#
#
#
#         circle_6245b45857f2dd0a76eefd859b1f46e6.bindPopup(popup_f4264b94d371c2184cb154d5b3dcef90)
#         ;
#
#
#
#
#             var circle_4fc9c56f3bbb0148ba0bca2253f5b158 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_7d4faae5cc6b58052169011591bc8bf1);
#
#
#         var popup_60978299dcdb4c3f46404b9bfcdbad3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16df2be3ca1214e3bcb53a7e5f4ecd50 = $(`&lt;div id=&quot;html_16df2be3ca1214e3bcb53a7e5f4ecd50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_60978299dcdb4c3f46404b9bfcdbad3e.setContent(html_16df2be3ca1214e3bcb53a7e5f4ecd50);
#
#
#
#         circle_4fc9c56f3bbb0148ba0bca2253f5b158.bindPopup(popup_60978299dcdb4c3f46404b9bfcdbad3e)
#         ;
#
#
#
#
#             var circle_00cb14008bebcde0b1a563bcbaa7235c = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_7d4faae5cc6b58052169011591bc8bf1);
#
#
#         var popup_a6c8a3ff6a4e57b8f6068b3ed9924eeb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb4d62a69f1433d2d38774f165b40b40 = $(`&lt;div id=&quot;html_cb4d62a69f1433d2d38774f165b40b40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_a6c8a3ff6a4e57b8f6068b3ed9924eeb.setContent(html_cb4d62a69f1433d2d38774f165b40b40);
#
#
#
#         circle_00cb14008bebcde0b1a563bcbaa7235c.bindPopup(popup_a6c8a3ff6a4e57b8f6068b3ed9924eeb)
#         ;
#
#
#
#
#             var circle_b8b21c1c09094789d309bbee234a825d = L.circle(
#                 [-33.920011, 18.642819],

# %%
# import folium
# from folium.plugins import HeatMap
# import numpy as np

# latitude, longitude = 48, 5

# data = (
#     np.random.normal(size=(100, 3)) *
#     np.array([[1, 1, 1]]) +
#     np.array([[48, 5, 1]])
# ).tolist()

# m = folium.Map([48, 5], zoom_start=10)

# HeatMap(data).add_to(folium.FeatureGroup(name='Heat Map').add_to(m))
# folium.LayerControl().add_to(m)

# m

# %%
suburbsArray = df_suburbs[['Latitude', 'Longitude']].values

# %%
suburbsArray
# Out:
# array([[-33.96722 ,  18.50214 ],
#        [-32.705958,  18.485135],
#        [-33.927953,  18.382592],
#        [-33.920011,  18.642819],
#        [-34.047464,  18.452499],
#        [-33.947283,  18.575133],
#        [-33.991092,  18.444217],
#        [-33.882677,  18.652075],
#        [-33.950161,  18.554446],
#        [-33.860418,  18.544612],
#        [-34.065011,  22.06257 ],
#        [-33.95    ,  18.533333],
#        [-33.90982 ,  18.481978],
#        [-33.985847,  18.45749 ],
#        [-33.934259,  18.378476],
#        [-34.124867,  18.432759],
#        [-34.01832 ,  18.441142],
#        [-33.926369,  18.593577],
#        [-33.978555,  18.50413 ],
#        [-33.994451,  18.595982],
#        [-33.841588,  18.651795],
#        [-33.85006 ,  18.638249],
#        [-33.874974,  18.542875],
#        [-33.999247,  18.734692],
#        [-34.589721,  19.757882],
#        [-33.935076,  18.577562],
#        [-33.93624 ,  18.487486],
#        [-33.936051,  18.404945],
#        [-33.974819,  18.701351],
#        [-34.155909,  18.41995 ],
#        [-34.047195,  18.498626],
#        [-33.910012,  18.403859],
#        [-33.983511,  18.570596],
#        [-33.994609,  18.529775],
#        [-33.933406,  20.074828],
#        [-34.047645,  18.46808 ],
#        [-33.964769,  18.548435],
#        [-34.033333,  18.35    ],
#        [-34.124958,  18.450676],
#        [-33.915435,  18.501743],
#        [-34.138929,  18.329108],
#        [-34.089125,  18.458681],
#        [-33.945057,  18.534307],
#        [-33.987354,  18.497457],
#        [-34.073458,  18.486572],
#        [-34.009198,  18.344159],
#        [-34.037828,  18.517059],
#        [-34.064046,  18.763337],
#        [-33.921734,  18.490299],
#        [-33.512728,  18.473736],
#        [-33.98972 ,  18.556274],
#        [-33.940598,  18.574469],
#        [-34.032796,  18.452906],
#        [-33.998061,  18.672907],
#        [-33.874573,  18.499149],
#        [-33.422832,  19.204617],
#        [-33.879053,  18.554474],
#        [-33.948024,  18.473333],
#        [-34.104509,  18.468289],
#        [-33.966667,  18.483333],
#        [-33.619813,  19.7421  ],
#        [-32.718097,  19.066886],
#        [-33.987472,  18.585457],
#        [-33.833333,  18.683333],
#        [-33.936126,  18.467872],
#        [-34.148613,  18.353646],
#        [-33.942532,  18.408982],
#        [-34.016785,  18.505041],
#        [-34.028863,  18.4955  ],
#        [-33.897228,  18.599924],
#        [-33.993096,  18.733482],
#        [-33.665835,  18.581233],
#        [-34.008747,  18.542716],
#        [-33.934769,  18.517694],
#        [-34.019091,  18.478345],
#        [-33.921362,  18.609081],
#        [-34.140273,  18.882027],
#        [-34.216818,  18.463655],
#        [-33.950865,  18.471641],
#        [-33.833333,  18.516667],
#        [-33.895717,  18.490115],
#        [-33.932547,  18.466182],
#        [-33.883289,  18.504209],
#        [-34.198909,  18.377605],
#        [-33.818626,  18.651614],
#        [-33.9198  ,  18.389271],
#        [-33.963653,  18.530105],
#        [-34.079375,  18.85699 ],
#        [-33.844689,  18.663242],
#        [-34.033874,  18.485929],
#        [-34.074425,  18.470234],
#        [-33.866088,  18.659923],
#        [-34.106869,  18.827513],
#        [-34.073097,  18.561189],
#        [-33.819128,  18.488102],
#        [-33.929411,  18.404388],
#        [-33.922449,  18.536199],
#        [-33.909067,  18.395743],
#        [-34.060458,  18.437825],
#        [-33.940992,  18.421302],
#        [-34.066379,  19.10953 ],
#        [-33.877069,  18.617141],
#        [-33.594102,  22.192635],
#        [-34.07607 ,  18.437924],
#        [-33.908311,  18.520216],
#        [-34.395474,  20.844846],
#        [-34.1     ,  18.383333],
#        [-33.931564,  18.444802],
#        [-33.983333,  18.4     ],
#        [-33.622557,  19.413941],
#        [-34.027804,  18.748525],
#        [-33.983333,  18.45    ],
#        [-33.604011,  18.970768],
#        [-34.098713,  18.385622],
#        [-34.101328,  18.389407],
#        [-34.039321,  18.679156],
#        [-33.848084,  18.717235],
#        [-33.863523,  18.520323],
#        [-33.900271,  18.405314],
#        [-34.25    ,  19.6     ],
#        [-33.906357,  18.490785]])
