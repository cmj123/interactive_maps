# %%
import folium
import pandas as pd

# %%
df_suburbs = pd.read_excel('waterwatch_clean2.xlsx', sheet_name='Sheet1')

df_suburbs.head()
# Out:
#    Unnamed: 0           Suburb  \
# 0           0          ATHLONE
# 1           1           AURORA
# 2           2       BANTRY BAY
# 3           3  BELLVILLE SOUTH
# 4           4        BERGVLIET
#
#    Number of single-residential properties_number  Oct 2017\nkl/month  \
# 0                                            2272                  11
# 1                                             426                  10
# 2                                             248                  13
# 3                                            2041                  11
# 4                                            1488                   8
#
#      Month  Year   Latitude  Longitude
# 0  October  2017 -33.967220  18.502140
# 1  October  2017 -32.705958  18.485135
# 2  October  2017 -33.927953  18.382592
# 3  October  2017 -33.920011  18.642819
# 4  October  2017 -34.047464  18.452499

# %%
df_suburbs.columns
# Out:
# Index(['Unnamed: 0', 'Suburb',
#        'Number of single-residential properties_number', 'Oct 2017\nkl/month',
#        'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_suburbs.shape
# Out:
# (121, 8)

# %%
df_suburbs.describe()
# Out:
#        Unnamed: 0  Number of single-residential properties_number  \
# count  121.000000                                      121.000000
# mean    60.000000                                     1849.983471
# std     35.073732                                     2506.756526
# min      0.000000                                        0.000000
# 25%     30.000000                                      364.000000
# 50%     60.000000                                     1009.000000
# 75%     90.000000                                     2411.000000
# max    120.000000                                    20719.000000
#
#        Oct 2017\nkl/month    Year    Latitude   Longitude
# count          121.000000   121.0  121.000000  121.000000
# mean             8.413223  2017.0  -33.944923   18.668673
# std              3.275336     0.0    0.217793    0.568946
# min              0.000000  2017.0  -34.589721   18.329108
# 25%              8.000000  2017.0  -34.037828   18.457490
# 50%              9.000000  2017.0  -33.950865   18.505041
# 75%             10.000000  2017.0  -33.908311   18.638249
# max             13.000000  2017.0  -32.705958   22.192635

# %%
map_osm = folium.Map(location=[-33.925, 18.625], zoom_start=10)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fa884041e5c01fdddfa3ec197b4a1ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fa884041e5c01fdddfa3ec197b4a1ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fa884041e5c01fdddfa3ec197b4a1ae = L.map(
#                 &quot;map_4fa884041e5c01fdddfa3ec197b4a1ae&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c9ae6fd653b4f4e413b245835c7eac6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_dark = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd0cfacbc7fae7d9e8562ca34b1f059e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd0cfacbc7fae7d9e8562ca34b1f059e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd0cfacbc7fae7d9e8562ca34b1f059e = L.map(
#                 &quot;map_bd0cfacbc7fae7d9e8562ca34b1f059e&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71a25e867dc36a89c042fbf4e9a39aec = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bd0cfacbc7fae7d9e8562ca34b1f059e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_suburbs_locations = df_suburbs[['Latitude', 'Longitude']]
#df_suburbs_locations
suburbs_location_list = df_suburbs_locations.values.tolist()
suburbs_location_list_size = len(suburbs_location_list)
suburbs_location_list_size
# Out:
# 121

# %%
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point]).add_to(map_osm)
    folium.Marker(suburbs_location_list[point]).add_to(map_dark)
    
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fa884041e5c01fdddfa3ec197b4a1ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fa884041e5c01fdddfa3ec197b4a1ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fa884041e5c01fdddfa3ec197b4a1ae = L.map(
#                 &quot;map_4fa884041e5c01fdddfa3ec197b4a1ae&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c9ae6fd653b4f4e413b245835c7eac6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_8b405fdd1c0eda7da1ca13e1ad6db824 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_ac399e82d866a57ef4a68ad81fdd1619 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_68107ccd7c6ab0cff237971674f88cf0 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_95fd1209bd220075ed4f3af72e227376 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_f0ad6c5e05e7b401d68b203bcb2b08b1 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_0dfb9679196f7c822d1f721ba88003b8 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_970165f70759c9a717aae847fadc111c = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_f8a4ea37d7315d3f42e097471b0f3982 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_ea9c1527a37ce325e9223b36263870a1 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_7d6b301a8ec26f71cfa6f9e8341e13e9 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_27ecfb0a26fca938b5701da62016ee01 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_4fa884041e5c01fdddfa3ec197b4a1ae);
#
#
#             var marker_
L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_bd0cfacbc7fae7d9e8562ca34b1f059e);
#
#
#             var marker_5d330f70ee3079b7204b783d2360731a = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_bd0cfacbc7fae7d9e8562ca34b1f059e);
#
#
#             var marker_b151c8a133daad102b8c1e6c52d57ee9 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_bd0cfacbc7fae7d9e8562ca34b1f059e);
#
#
#             var marker_019e4ffab7f001dddce1a8a8160f0bf3 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_bd0cfacbc7fae7d9e8562ca34b1f059e);
#
#
#             var marker_1bb7542bf7cbada733ecfd8dc43cb9f3 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_bd0cfacbc7fae7d9e8562ca34b1f059e);
#
#
#             var marker_eb954bdf12387d2645ecb99b30624ba6 =

# %%
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c22b81d47e09f2b9a3d1b68ad91a822 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c22b81d47e09f2b9a3d1b68ad91a822&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c22b81d47e09f2b9a3d1b68ad91a822 = L.map(
#                 &quot;map_1c22b81d47e09f2b9a3d1b68ad91a822&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d752c12ca3b162ed50108fc415ef1b69 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c22b81d47e09f2b9a3d1b68ad91a822);
#
#
#             var circle_971dbc4b66bbb78118197d46a42e61bf = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_1c22b81d47e09f2b9a3d1b68ad91a822);
#
#
#         var popup_d9fba12bb86e898dd03b91b8779eb4d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1b11fc2ef1de7971d5903f0b6c8389e = $(`&lt;div id=&quot;html_e1b11fc2ef1de7971d5903f0b6c8389e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_d9fba12bb86e898dd03b91b8779eb4d3.setContent(html_e1b11fc2ef1de7971d5903f0b6c8389e);
#
#
#
#         circle_971dbc4b66bbb78118197d46a42e61bf.bindPopup(popup_d9fba12bb86e898dd03b91b8779eb4d3)
#         ;
#
#
#
#
#             var circle_8cab8a823c4a491f8934b4507b2a4efd = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_1c22b81d47e09f2b9a3d1b68ad91a822);
#
#
#         var popup_b1142386b01dfa503ba2dac11b7da222 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e01c1896baceeaacb6542bc07df0dca1 = $(`&lt;div id=&quot;html_e01c1896baceeaacb6542bc07df0dca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_b1142386b01dfa503ba2dac11b7da222.setContent(html_e01c1896baceeaacb6542bc07df0dca1);
#
#
#
#         circle_8cab8a823c4a491f8934b4507b2a4efd.bindPopup(popup_b1142386b01dfa503ba2dac11b7da222)
#         ;
#
#
#
#
#             var circle_4312fab292fc95b210077c612de8b503 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_1c22b81d47e09f2b9a3d1b68ad91a822);
#
#
#         var popup_55dae952a70fe3f1483e6f9dd46d8615 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e3c49e12c17e77018c6a3ded5840781 = $(`&lt;div id=&quot;html_0e3c49e12c17e77018c6a3ded5840781&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_55dae952a70fe3f1483e6f9dd46d8615.setContent(html_0e3c49e12c17e77018c6a3ded5840781);
#
#
#
#         circle_4312fab292fc95b210077c612de8b503.bindPopup(popup_55dae952a70fe3f1483e6f9dd46d8615)
#         ;
#
#
#
#
#             var circle_ddcc7d33e8db82b4684eb9f3d54fc818 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &

# %%
# Adding Classification
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    # Classify by usage
    if df_suburbs['Oct 2017\nkl/month'][point] <= 8 and df_suburbs['Oct 2017\nkl/month'][point] > 0:
        usage_color = 'green'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 8 and df_suburbs['Oct 2017\nkl/month'][point] <= 10:
        usage_color = '#17cbef'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 10:
        usage_color = 'red'
    else: # Outliers
        usage_color = 'orange'
        
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color=usage_color,
        fill=True,
        opacity=0.8,
        fill_color=usage_color,
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77d64a8eaf3559d9afb4d1678824d7ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77d64a8eaf3559d9afb4d1678824d7ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77d64a8eaf3559d9afb4d1678824d7ca = L.map(
#                 &quot;map_77d64a8eaf3559d9afb4d1678824d7ca&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9078fe0f2e66b2418c1e6fe731595ad7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77d64a8eaf3559d9afb4d1678824d7ca);
#
#
#             var circle_988ecce481017f734b9852775b87fddf = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_77d64a8eaf3559d9afb4d1678824d7ca);
#
#
#         var popup_f7a65f4ee302ea062b3e513a81a44454 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78688dabe23a669d583a104d925f64e2 = $(`&lt;div id=&quot;html_78688dabe23a669d583a104d925f64e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_f7a65f4ee302ea062b3e513a81a44454.setContent(html_78688dabe23a669d583a104d925f64e2);
#
#
#
#         circle_988ecce481017f734b9852775b87fddf.bindPopup(popup_f7a65f4ee302ea062b3e513a81a44454)
#         ;
#
#
#
#
#             var circle_ca1e1456cefdc22bed87598e19fd6705 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_77d64a8eaf3559d9afb4d1678824d7ca);
#
#
#         var popup_7c05dc7d97fea9010a401e2511e9305e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6fadc8033513affa630f81820fa3d29 = $(`&lt;div id=&quot;html_c6fadc8033513affa630f81820fa3d29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_7c05dc7d97fea9010a401e2511e9305e.setContent(html_c6fadc8033513affa630f81820fa3d29);
#
#
#
#         circle_ca1e1456cefdc22bed87598e19fd6705.bindPopup(popup_7c05dc7d97fea9010a401e2511e9305e)
#         ;
#
#
#
#
#             var circle_3be9491de4af78b6c120e3e71e263ad5 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_77d64a8eaf3559d9afb4d1678824d7ca);
#
#
#         var popup_8eaadfafd9e96d366013edb154c3ea75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e747b0ee3e7e8b470428aa761845501 = $(`&lt;div id=&quot;html_7e747b0ee3e7e8b470428aa761845501&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_8eaadfafd9e96d366013edb154c3ea75.setContent(html_7e747b0ee3e7e8b470428aa761845501);
#
#
#
#         circle_3be9491de4af78b6c120e3e71e263ad5.bindPopup(popup_8eaadfafd9e96d366013edb154c3ea75)
#         ;
#
#
#
#
#             var circle_c5573e88bee685afee8c69a91551361e = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru

# %%
# Building choropleth map

df_world_countries = pd.read_json('world-countries.json')
df_unemployment = pd.read_csv('unemployment.csv', skiprows=4, delimiter=',')

df_unemployment
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 1    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 2    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 3    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 4    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# ..                                                 ...             ...   ...
# 259  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 260  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 261  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 262  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 263  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010   2011    2012    2013  \
# 0     NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# 1     NaN   NaN   NaN   NaN   NaN  ...   7.821000   8.23   7.936   8.452
# 2     NaN   NaN   NaN   NaN   NaN  ...   9.863000   7.36   7.347   7.331
# 3     NaN   NaN   NaN   NaN   NaN  ...  14.200000  13.98  13.440  15.640
# 4     NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# ..    ...   ...   ...   ...   ...  ...        ...    ...     ...     ...
# 259   NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# 260   NaN   NaN   NaN   NaN   NaN  ...  17.820000  16.99  15.277  14.163
# 261   NaN   NaN   NaN   NaN   NaN  ...  24.690001  24.65  24.730  24.570
# 262   NaN   NaN   NaN   NaN   NaN  ...  13.190000   9.99   7.850   7.816
# 263   NaN   NaN   NaN   NaN   NaN  ...   5.272000   5.37   5.328   5.205
#
#        2014    2015       2016    2017       2018  Unnamed: 63
# 0       NaN     NaN        NaN     NaN        NaN          NaN
# 1     8.706   8.864   8.841000   8.837   8.808000          NaN
# 2     7.306   7.281   7.724000   8.167   8.543000          NaN
# 3    17.490  17.080  15.220000  13.867  15.132000          NaN
# 4       NaN     NaN        NaN     NaN        NaN          NaN
# ..      ...     ...        ...     ...        ...          ...
# 259     NaN     NaN        NaN     NaN        NaN          NaN
# 260  13.470  13.807  13.729000  14.036  14.167000          NaN
# 261  24.900  25.160  26.549999  27.330  27.372999          NaN
# 262   7.783   7.750   7.777000   7.792   7.797000          NaN
# 263   5.135   5.086   5.046000   5.011   4.985000          NaN
#
# [264 rows x 64 columns]

# %%
df_unemployment_2018 = df_unemployment[['Country Name', 'Country Code', '2018']]
df_unemployment_2018.head(10)
# Out:
#            Country Name Country Code       2018
# 0                 Aruba          ABW        NaN
# 1           Afghanistan          AFG   8.808000
# 2                Angola          AGO   8.543000
# 3               Albania          ALB  15.132000
# 4               Andorra          AND        NaN
# 5            Arab World          ARB   9.808109
# 6  United Arab Emirates          ARE   1.710000
# 7             Argentina          ARG   8.162000
# 8               Armenia          ARM  18.275999
# 9        American Samoa          ASM        NaN

# %%
# Remove nulls

df_unemployment_2018_clean = df_unemployment_2018.dropna()
df_unemployment_2018_clean.head(10)
# Out:
#             Country Name Country Code       2018
# 1            Afghanistan          AFG   8.808000
# 2                 Angola          AGO   8.543000
# 3                Albania          ALB  15.132000
# 5             Arab World          ARB   9.808109
# 6   United Arab Emirates          ARE   1.710000
# 7              Argentina          ARG   8.162000
# 8                Armenia          ARM  18.275999
# 11             Australia          AUS   5.474000
# 12               Austria          AUT   5.387000
# 13            Azerbaijan          AZE   5.037000

# %%
df_unemployment_2018_clean.shape
# Out:
# (233, 3)

# %%
# prepare data for our map
legendTitle = 'Unemployment rate per country 2018 (%)'

# Data to plot country code and value
data_unemployment = df_unemployment_2018_clean[['Country Code', '2018']]

data_unemployment.head()
# Out:
#   Country Code       2018
# 1          AFG   8.808000
# 2          AGO   8.543000
# 3          ALB  15.132000
# 5          ARB   9.808109
# 6          ARE   1.710000

# %%
# Setup the map
map_unemployment = folium.Map(location=[8.7832, 34.5085], zoom_start=3)

map_unemployment.choropleth(geo_data='world-countries.json',
                           data=data_unemployment,
                           columns=['Country Code', '2018'],
                           key_on='feature.id',
                           fill_color='YlOrRd',
                           fill_opacity=0.7,
                           line_opacity=0.2,
                           legend_name=legendTitle)

map_unemployment
# Out:
# /Users/esuabomdijemeni/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/folium/folium.py:411: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b96492a76be36b17d14d45c3dedd5702 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b96492a76be36b17d14d45c3dedd5702&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b96492a76be36b17d14d45c3dedd5702 = L.map(
#                 &quot;map_b96492a76be36b17d14d45c3dedd5702&quot;,
#                 {
#                     center: [8.7832, 34.5085],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e359b1868050bbcd8f27bf4acd0ace37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b96492a76be36b17d14d45c3dedd5702);
#
#
#             var choropleth_8627c37cf68ee924e31cb2c1cb7f4fd3 = L.featureGroup(
#                 {}
#             ).addTo(map_b96492a76be36b17d14d45c3dedd5702);
#
#
#         function geo_json_d4ebd00bee563c5265935e97bdba70ef_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Afghanistan&quot;: case &quot;Angola&quot;: case &quot;Argentina&quot;: case &quot;Australia&quot;: case &quot;Austria&quot;: case &quot;Azerbaijan&quot;: case &quot;Belgium&quot;: case &quot;Burkina Faso&quot;: case &quot;Bulgaria&quot;: case &quot;Belize&quot;: case &quot;Brunei&quot;: case &quot;Central African Republic&quot;: case &quot;Canada&quot;: case &quot;Chile&quot;: case &quot;Colombia&quot;: case &quot;Costa Rica&quot;: case &quot;Djibouti&quot;: case &quot;Denmark&quot;: case &quot;Dominican Republic&quot;: case &quot;Eritrea&quot;: case &quot;Estonia&quot;: case &quot;Ethiopia&quot;: case &quot;Finland&quot;: case &quot;Fiji&quot;: case &quot;France&quot;: case &quot;Gambia&quot;: case &quot;Guinea Bissau&quot;: case &quot;Equatorial Guinea&quot;: case &quot;Croatia&quot;: case &quot;Ireland&quot;: case &quot;Iraq&quot;: case &quot;Kazakhstan&quot;: case &quot;Kyrgyzstan&quot;: case &quot;Lebanon&quot;: case &quot;Lithuania&quot;: case &quot;Luxembourg&quot;: case &quot;Latvia&quot;: case &quot;Morocco&quot;: case &quot;Mali&quot;: case &quot;Mongolia&quot;: case &quot;Malawi&quot;: case &quot;Nigeria&quot;: case &quot;New Zealand&quot;: case &quot;Portugal&quot;: case &quot;Russia&quot;: case &quot;Saudi Arabia&quot;: case &quot;Somalia&quot;: case &quot;Suriname&quot;: case &quot;Slovakia&quot;: case &quot;Slovenia&quot;: case &quot;Sweden&quot;: case &quot;Chad&quot;: case &quot;Trinidad and Tobago&quot;: case &quot;Ukraine&quot;: case &quot;Uruguay&quot;: case &quot;Uzbekistan&quot;: case &quot;Venezuela&quot;: case &quot;Vanuatu&quot;: case &quot;Zambia&quot;: case &quot;Zimbabwe&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Albania&quot;: case &quot;Armenia&quot;: case &quot;Botswana&quot;: case &quot;Spain&quot;: case &quot;Jordan&quot;: case &quot;Libya&quot;: case &quot;Montenegro&quot;: case &quot;New Caledonia&quot;: case &quot;Syria&quot;: case &quot;Tunisia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Antarctica&quot;: case &quot;French Southern and Antarctic Lands&quot;: case &quot;Northern Cyprus&quot;: case &quot;Falkland Islands&quot;: case &quot;Greenland&quot;: case &quot;Kosovo&quot;: case &quot;Western Sahara&quot;: case &quot;South Sudan&quot;: case &quot;Somaliland&quot;: case &quot;Taiwan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;The Bahamas&quot;: case &quot;Brazil&quot;: case &quot;Republic of the Congo&quot;: case &quot;Cyprus&quot;: case &quot;Algeria&quot;: case &quot;Egypt&quot;: case &quot;Georgia&quot;: case &quot;Guyana&quot;: case &quot;Haiti&quot;: case &quot;Iran&quot;: case &quot;Italy&quot;: case &quot;Jamaica&quot;: case &quot;Kenya&quot;: case &quot;Mauritania&quot;: case &quot;Puerto Rico&quot;: case &quot;Sudan&quot;: case &quot;Republic of Serbia&quot;: case &quot;Tajikistan&quot;: case &quot;Turkey&quot;: case &quot;Yemen&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Bosnia and Herzegovina&quot;: case &quot;Lesotho&quot;: case &quot;Mozambique&quot;: case &quot;Swaziland&quot;: case &quot;West Bank&quot;: case &quot;South Africa&quot;:

# %%
# Measuring Boundries

df_damLevels = pd.read_csv('https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/master/DamLevels.txt', delimiter=',')

df_damLevels.head()
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras Dam-Lower        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras Dam-Upper        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
#
#    ThisWeek  LastWeek  LastYear
# 0      73.7      75.2      49.9
# 1      50.2      51.7      35.6
# 2      70.0      69.8      92.4
# 3      40.9      41.9      10.6
# 4      65.6      67.5      15.5

# %%
df_location = pd.read_csv('https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/master/damLocations.txt', delimiter=',')

df_location.head()
# Out:
#                    Dam   Latitude  Longitude
# 0       Berg River Dam -33.925000  19.060833
# 1  Steenbras Dam-Upper -34.166300  18.910000
# 2  Steenbras Dam-Lower -34.179722  18.876389
# 3  Theewaterskloof Dam -34.078100  19.289200
# 4         Voelvlei Dam -33.337500  19.033600

# %%
# Join the two dataframes on the dam field
df_damData = pd.merge(df_damLevels, df_location, on='Dam', how='left')

df_damData.head()
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras Dam-Lower        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras Dam-Upper        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
#
#    ThisWeek  LastWeek  LastYear   Latitude  Longitude
# 0      73.7      75.2      49.9 -33.925000  19.060833
# 1      50.2      51.7      35.6 -34.179722  18.876389
# 2      70.0      69.8      92.4 -34.166300  18.910000
# 3      40.9      41.9      10.6 -34.078100  19.289200
# 4      65.6      67.5      15.5 -33.337500  19.033600

# %%
# Prepare data to plot
df_dams_locations = df_damData[['Latitude', 'Longitude']]
dams_location_list = df_dams_locations.values.tolist()
dams_location_list_size = len(dams_location_list)
dams_location_list_size
# Out:
# 6

# %%
map_dams = folium.Map(location=[-33.925, 18.625], zoom_start=10)
for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_dams)
    
map_dams
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6621e4f6aac232515c6c2f6c8aef015a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6621e4f6aac232515c6c2f6c8aef015a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6621e4f6aac232515c6c2f6c8aef015a = L.map(
#                 &quot;map_6621e4f6aac232515c6c2f6c8aef015a&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_583e87344c1ea3e8d8ccb266b6601a9e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6621e4f6aac232515c6c2f6c8aef015a);
#
#
#             var marker_86c0a7b97bd4f0ecd9574fe96dfd12b2 = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_6621e4f6aac232515c6c2f6c8aef015a);
#
#
#         var popup_94379bfce206f37126d0427049708173 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_085bedbecaa47d48199a8ec366919d42 = $(`&lt;div id=&quot;html_085bedbecaa47d48199a8ec366919d42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_94379bfce206f37126d0427049708173.setContent(html_085bedbecaa47d48199a8ec366919d42);
#
#
#
#         marker_86c0a7b97bd4f0ecd9574fe96dfd12b2.bindPopup(popup_94379bfce206f37126d0427049708173)
#         ;
#
#
#
#
#             var marker_9b862c07fc9925592cce94c516ecdc6c = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_6621e4f6aac232515c6c2f6c8aef015a);
#
#
#         var popup_7bcb08ed1e17763e550dc2c65f0b2359 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_590345ded48374dacdee65338a34557d = $(`&lt;div id=&quot;html_590345ded48374dacdee65338a34557d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_7bcb08ed1e17763e550dc2c65f0b2359.setContent(html_590345ded48374dacdee65338a34557d);
#
#
#
#         marker_9b862c07fc9925592cce94c516ecdc6c.bindPopup(popup_7bcb08ed1e17763e550dc2c65f0b2359)
#         ;
#
#
#
#
#             var marker_3ba4700d3b8ac5dbc4bdb741d2691340 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_6621e4f6aac232515c6c2f6c8aef015a);
#
#
#         var popup_68106a2a3928b9206f021154ad425807 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_329cda06a080d4a35d2deaeef85007c3 = $(`&lt;div id=&quot;html_329cda06a080d4a35d2deaeef85007c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_68106a2a3928b9206f021154ad425807.setContent(html_329cda06a080d4a35d2deaeef85007c3);
#
#
#
#         marker_3ba4700d3b8ac5dbc4bdb741d2691340.bindPopup(popup_68106a2a3928b9206f021154ad425807)
#         ;
#
#
#
#
#             var marker_f4595ba0a6efa4ba4650ea931ebbb2cb = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_6621e4f6aac232515c6c2f6c8aef015a);
#
#
#         var popup_6117a5212fa0791aeb820e44c1ad90c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f03ae6ca681a69897f3a27ff9a3fa7a0 = $(`&lt;div id=&quot;html_f03ae6ca681a69897f3a27ff9a3fa7a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_6117a5212fa0791aeb820e44c1ad90c1.setContent(html_f03ae6ca681a69897f3a27ff9a3fa7a0);
#
#
#
#         marker_f4595ba0a6efa4ba4650ea931ebbb2cb.bindPopup(popup_6117a5212fa0791aeb820e44c1ad90c1)
#         ;
#
#
#
#
#             var marker_24bf4a766f8b311d5415341fc34642fa = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_6621e4f6aac232515c6c2f6c8aef015a);
#
#
#         var popup_8bfecfe1a55f354d87123630d8adb3d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9fc3898a7c1fe5713a27217517935317 = $(`&lt;div id=&quot;html_9fc3898a7c1fe5713a27217517935317&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_8bfecfe1a55f354d87123630d8adb3d6.setContent(html_9fc3898a7c1fe5713a27217517935317);
#
#
#
#         marker_24bf4a766f8b311d5415341fc34642fa.bindPopup(popup_8bfecfe1a55f354d87123630d8adb3d6)
#         ;
#
#
#
#
#             var marker_65dc63e16d3ba7c93b9657dca76d4c05 = L.marker(
#                 [-33.8336, 19.0889],
#                 {}
#             ).addTo(map_6621e4f6aac232515c6c2f6c8aef015a);
#
#
#         var popup_447e6f0baea7aec9fdb86d7b408cf4

# %%
map_url = folium.Map(location=[-34.078100, 19.289200],
                    tiles='http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                    zoom_start=12,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community')

for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_url)

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_028c801a0a1ffde11f6255691ea69fc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_028c801a0a1ffde11f6255691ea69fc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_028c801a0a1ffde11f6255691ea69fc8 = L.map(
#                 &quot;map_028c801a0a1ffde11f6255691ea69fc8&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1c3689a38533acd5bec90bbb1951611 = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#             var marker_3b69b35acf0c1e8a1db18df4d498b2b3 = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_9e18b551f56fdc44c46ba69e8d283379 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63046b5b4dacfe2226f98e92aa17cdba = $(`&lt;div id=&quot;html_63046b5b4dacfe2226f98e92aa17cdba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_9e18b551f56fdc44c46ba69e8d283379.setContent(html_63046b5b4dacfe2226f98e92aa17cdba);
#
#
#
#         marker_3b69b35acf0c1e8a1db18df4d498b2b3.bindPopup(popup_9e18b551f56fdc44c46ba69e8d283379)
#         ;
#
#
#
#
#             var marker_7f0777894866217ea3c72a8d28bb3e36 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_2f653b3182b8519c06e254e71814a35b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_272ed226f2aabbcc834732862f241b7e = $(`&lt;div id=&quot;html_272ed226f2aabbcc834732862f241b7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_2f653b3182b8519c06e254e71814a35b.setContent(html_272ed226f2aabbcc834732862f241b7e);
#
#
#
#         marker_7f0777894866217ea3c72a8d28bb3e36.bindPopup(popup_2f653b3182b8519c06e254e71814a35b)
#         ;
#
#
#
#
#             var marker_1f589c112c7e3c20f663bc45ea3c7c96 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_84425cbc878b0930a7f34454d250a1f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c99adc7b07cbfded92121e2207b8055 = $(`&lt;div id=&quot;html_0c99adc7b07cbfded92121e2207b8055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_84425cbc878b0930a7f34454d250a1f8.setContent(html_0c99adc7b07cbfded92121e2207b8055);
#
#
#
#         marker_1f589c112c7e3c20f663bc45ea3c7c96.bindPopup(popup_84425cbc878b0930a7f34454d250a1f8)
#         ;
#
#
#
#
#             var marker_b950a2fa6c897685ddd73fa58d756bf5 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_3ee2df9b6b9cec9b2b10ced0531b77bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ea532a62af3d1e59c94440b25bbdfaa = $(`&lt;div id=&quot;html_2ea532a62af3d1e59c94440b25bbdfaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_3ee2df9b6b9cec9b2b10ced0531b77bd.setContent(html_2ea532a62af3d1e59c94440b25bbdfaa);
#
#
#
#         marker_b950a2fa6c897685ddd73fa58d756bf5.bindPopup(popup_3ee2df9b6b9cec9b2b10ced0531b77bd)
#         ;
#
#
#
#
#             var marker_f587dbe1234f9866d5ccc3587eaf7857 = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_a31325eb73417b7343f6e6f6733fe5c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e2ba408c5fb89a246fa050ff1778965 = $(`&lt;div id=&quot;html_2e2ba408c5fb89a246fa050ff1778965&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_a31325eb73417b7343f6e6f6733fe5c4.setContent(html_2e2ba408c5fb89a246fa050ff1778965);
#
#
#
#         marker_f587dbe1234f9866d5ccc3587eaf7857.bindPopup(popup_a31325eb73417b7343f6e6f6733fe5c4)
#         ;
#
#
#
#
#             var marker_83ef129142adfebb842999c183f623c8 = L.marker(
#                 [-33.8336, 19.0889],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_78224c7b4f0dd41a4105bc7ecde5bfe0 =

# %%
from folium.plugins import MeasureControl

map_url.add_child(MeasureControl())

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_028c801a0a1ffde11f6255691ea69fc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_028c801a0a1ffde11f6255691ea69fc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_028c801a0a1ffde11f6255691ea69fc8 = L.map(
#                 &quot;map_028c801a0a1ffde11f6255691ea69fc8&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1c3689a38533acd5bec90bbb1951611 = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#             var marker_3b69b35acf0c1e8a1db18df4d498b2b3 = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_9e18b551f56fdc44c46ba69e8d283379 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63046b5b4dacfe2226f98e92aa17cdba = $(`&lt;div id=&quot;html_63046b5b4dacfe2226f98e92aa17cdba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_9e18b551f56fdc44c46ba69e8d283379.setContent(html_63046b5b4dacfe2226f98e92aa17cdba);
#
#
#
#         marker_3b69b35acf0c1e8a1db18df4d498b2b3.bindPopup(popup_9e18b551f56fdc44c46ba69e8d283379)
#         ;
#
#
#
#
#             var marker_7f0777894866217ea3c72a8d28bb3e36 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_2f653b3182b8519c06e254e71814a35b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_272ed226f2aabbcc834732862f241b7e = $(`&lt;div id=&quot;html_272ed226f2aabbcc834732862f241b7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_2f653b3182b8519c06e254e71814a35b.setContent(html_272ed226f2aabbcc834732862f241b7e);
#
#
#
#         marker_7f0777894866217ea3c72a8d28bb3e36.bindPopup(popup_2f653b3182b8519c06e254e71814a35b)
#         ;
#
#
#
#
#             var marker_1f589c112c7e3c20f663bc45ea3c7c96 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_84425cbc878b0930a7f34454d250a1f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c99adc7b07cbfded92121e2207b8055 = $(`&lt;div id=&quot;html_0c99adc7b07cbfded92121e2207b8055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_84425cbc878b0930a7f34454d250a1f8.setContent(html_0c99adc7b07cbfded92121e2207b8055);
#
#
#
#         marker_1f589c112c7e3c20f663bc45ea3c7c96.bindPopup(popup_84425cbc878b0930a7f34454d250a1f8)
#         ;
#
#
#
#
#             var marker_b950a2fa6c897685ddd73fa58d756bf5 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_3ee2df9b6b9cec9b2b10ced0531b77bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ea532a62af3d1e59c94440b25bbdfaa = $(`&lt;div id=&quot;html_2ea532a62af3d1e59c94440b25bbdfaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_3ee2df9b6b9cec9b2b10ced0531b77bd.setContent(html_2ea532a62af3d1e59c94440b25bbdfaa);
#
#
#
#         marker_b950a2fa6c897685ddd73fa58d756bf5.bindPopup(popup_3ee2df9b6b9cec9b2b10ced0531b77bd)
#         ;
#
#
#
#
#             var marker_f587dbe1234f9866d5ccc3587eaf7857 = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_028c801a0a1ffde11f6255691ea69fc8);
#
#
#         var popup_a31325eb73417b7343f6e6f6733fe5c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e2ba408c5fb89a246fa050ff1778965 = $(`&lt;div id=&quot;html_2e2ba408c5fb89a246fa050ff1778965&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_a31325eb73417b7343f6e6f6733fe5c4.setContent(html_2e2ba408c5fb89a246fa050ff1778965);
#
#
#
#         marker_f587dbe1234f9866d5ccc3587eaf7857.bindPopup(popup_a31325eb73417b7343f6e6f6733fe5c

# %%
# Add Layer Control
map_layers = map_points

add = '/MapServer/tile/{z}/{y}/{x}'
ESRI = dict(World_Ocean_Base='http://services.arcgisonline.com/arcgis/rest/services/Ocean/World_Ocean_Base',
            World_Navigation_Charts='http://services.arcgisonline.com/ArcGIS/rest/services/Specialty/World_Navigation_Charts',
            NatGeo_World_Map='http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer',
            World_Imagery='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer',
            World_Physical_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Physical_Map/MapServer',
            World_Shaded_Relief='http://services.arcgisonline.com/arcgis/rest/services/World_Shaded_Relief/MapServer',
            World_Street_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Street_Map/MapServer',
            World_Terrain_Base='http://services.arcgisonline.com/arcgis/rest/services/World_Terrain_Base/MapServer',
            World_Topo_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Topo_Map/MapServer')


for tile_name, tile_url in ESRI.items():
    tile_url += add
    folium.TileLayer(tile_url,
                    name=tile_name,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community').add_to(map_points)
    

folium.LayerControl().add_to(map_layers)

map_layers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77d64a8eaf3559d9afb4d1678824d7ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77d64a8eaf3559d9afb4d1678824d7ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77d64a8eaf3559d9afb4d1678824d7ca = L.map(
#                 &quot;map_77d64a8eaf3559d9afb4d1678824d7ca&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9078fe0f2e66b2418c1e6fe731595ad7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77d64a8eaf3559d9afb4d1678824d7ca);
#
#
#             var circle_988ecce481017f734b9852775b87fddf = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_77d64a8eaf3559d9afb4d1678824d7ca);
#
#
#         var popup_f7a65f4ee302ea062b3e513a81a44454 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78688dabe23a669d583a104d925f64e2 = $(`&lt;div id=&quot;html_78688dabe23a669d583a104d925f64e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_f7a65f4ee302ea062b3e513a81a44454.setContent(html_78688dabe23a669d583a104d925f64e2);
#
#
#
#         circle_988ecce481017f734b9852775b87fddf.bindPopup(popup_f7a65f4ee302ea062b3e513a81a44454)
#         ;
#
#
#
#
#             var circle_ca1e1456cefdc22bed87598e19fd6705 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_77d64a8eaf3559d9afb4d1678824d7ca);
#
#
#         var popup_7c05dc7d97fea9010a401e2511e9305e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6fadc8033513affa630f81820fa3d29 = $(`&lt;div id=&quot;html_c6fadc8033513affa630f81820fa3d29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_7c05dc7d97fea9010a401e2511e9305e.setContent(html_c6fadc8033513affa630f81820fa3d29);
#
#
#
#         circle_ca1e1456cefdc22bed87598e19fd6705.bindPopup(popup_7c05dc7d97fea9010a401e2511e9305e)
#         ;
#
#
#
#
#             var circle_3be9491de4af78b6c120e3e71e263ad5 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_77d64a8eaf3559d9afb4d1678824d7ca);
#
#
#         var popup_8eaadfafd9e96d366013edb154c3ea75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e747b0ee3e7e8b470428aa761845501 = $(`&lt;div id=&quot;html_7e747b0ee3e7e8b470428aa761845501&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_8eaadfafd9e96d366013edb154c3ea75.setContent(html_7e747b0ee3e7e8b470428aa761845501);
#
#
#
#         circle_3be9491de4af78b6c120e3e71e263ad5.bindPopup(popup_8eaadfafd9e96d366013edb154c3ea75)
#         ;
#
#
#
#
#             var circle_c5573e88bee685afee8c69a91551361e = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru

# %%
# Creating Heatmap

from folium.plugins import HeatMap

# Create our point map object
map_heat = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius='15',
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_heat)
    
# convert to array format for our heatmap
suburbsArray = df_suburbs[['Latitude', 'Longitude']].values

# plot heatmap
map_heat.add_child(HeatMap(suburbsArray))

map_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78aeae568c1b7be1ed57d08229def46f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78aeae568c1b7be1ed57d08229def46f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78aeae568c1b7be1ed57d08229def46f = L.map(
#                 &quot;map_78aeae568c1b7be1ed57d08229def46f&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8118d301dca08a2f9a1eefec92b9c66e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_78aeae568c1b7be1ed57d08229def46f);
#
#
#             var circle_5dc89cca4e31b144a167667877f751d4 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_78aeae568c1b7be1ed57d08229def46f);
#
#
#         var popup_befb9082cbde3be29614b5f864476736 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e39b4f74db79d085321efe334be3689 = $(`&lt;div id=&quot;html_4e39b4f74db79d085321efe334be3689&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_befb9082cbde3be29614b5f864476736.setContent(html_4e39b4f74db79d085321efe334be3689);
#
#
#
#         circle_5dc89cca4e31b144a167667877f751d4.bindPopup(popup_befb9082cbde3be29614b5f864476736)
#         ;
#
#
#
#
#             var circle_f8408807f5e2f25c7a129660488b6a48 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_78aeae568c1b7be1ed57d08229def46f);
#
#
#         var popup_28484b905e554d28f1fa1dbb1984c6fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d65023f46f6cf46045925724a1e80743 = $(`&lt;div id=&quot;html_d65023f46f6cf46045925724a1e80743&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_28484b905e554d28f1fa1dbb1984c6fd.setContent(html_d65023f46f6cf46045925724a1e80743);
#
#
#
#         circle_f8408807f5e2f25c7a129660488b6a48.bindPopup(popup_28484b905e554d28f1fa1dbb1984c6fd)
#         ;
#
#
#
#
#             var circle_933605e9ae4d561b33f930f0e5b37e7c = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_78aeae568c1b7be1ed57d08229def46f);
#
#
#         var popup_02de68bc4b73a1b94260786a87506c5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bfabae13681779a8cdc59e78825b7a6d = $(`&lt;div id=&quot;html_bfabae13681779a8cdc59e78825b7a6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_02de68bc4b73a1b94260786a87506c5e.setContent(html_bfabae13681779a8cdc59e78825b7a6d);
#
#
#
#         circle_933605e9ae4d561b33f930f0e5b37e7c.bindPopup(popup_02de68bc4b73a1b94260786a87506c5e)
#         ;
#
#
#
#
#             var circle_9bf5da80ae16364c3b7c7975b2c99fb6 = L.circle(
#                 [-33.920011, 18.642819],

# %%
# !pip install selenium

# %%
import os
import time
from selenium import webdriver
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/tl/q1c606q156xbmnyd03bvkf7r0000gn/T/ipykernel_30822/94547548.py in <module>
#       1 import os
#       2 import time
# ----> 3 from selenium import webdriver
#
# ModuleNotFoundError: No module named 'selenium'

# %%
delay = 5

heat = 'map_heat.html'
unemployment = 'map_unemployment.html'

def export_maps(map_file, map_image, map_obj):
    browser = webdriver.Chrome('C:\\Users\\Edwin\\Downloads\\chromedriver_win32\\chromedriver.exe')
    tmpUrl = 'file://{path}/{mapfile}'.format(path=os.getcwd(), mapfile=map_file)
    map_obj.save(map_file)
    browser.get(tmpUrl)
    time.sleep(delay)
    browser.save_screenshot(map_image)
    browser.quit()
    
export_maps(heat, 'map_heat.png', map_heat)

# %%
export_maps(unemployment, 'map_unemployment.png', map_unemployment)
