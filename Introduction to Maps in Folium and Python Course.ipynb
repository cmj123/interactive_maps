# %%
import folium
import pandas as pd

# %%
df_suburbs = pd.read_excel('waterwatch_clean2.xlsx', sheet_name='Sheet1')

df_suburbs.head()
# Out:
#    Unnamed: 0           Suburb  \
# 0           0          ATHLONE
# 1           1           AURORA
# 2           2       BANTRY BAY
# 3           3  BELLVILLE SOUTH
# 4           4        BERGVLIET
#
#    Number of single-residential properties_number  Oct 2017\nkl/month  \
# 0                                            2272                  11
# 1                                             426                  10
# 2                                             248                  13
# 3                                            2041                  11
# 4                                            1488                   8
#
#      Month  Year   Latitude  Longitude
# 0  October  2017 -33.967220  18.502140
# 1  October  2017 -32.705958  18.485135
# 2  October  2017 -33.927953  18.382592
# 3  October  2017 -33.920011  18.642819
# 4  October  2017 -34.047464  18.452499

# %%
df_suburbs.columns
# Out:
# Index(['Unnamed: 0', 'Suburb',
#        'Number of single-residential properties_number', 'Oct 2017\nkl/month',
#        'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_suburbs.shape
# Out:
# (121, 8)

# %%
df_suburbs.describe()
# Out:
#        Unnamed: 0  Number of single-residential properties_number  \
# count  121.000000                                      121.000000
# mean    60.000000                                     1849.983471
# std     35.073732                                     2506.756526
# min      0.000000                                        0.000000
# 25%     30.000000                                      364.000000
# 50%     60.000000                                     1009.000000
# 75%     90.000000                                     2411.000000
# max    120.000000                                    20719.000000
#
#        Oct 2017\nkl/month    Year    Latitude   Longitude
# count          121.000000   121.0  121.000000  121.000000
# mean             8.413223  2017.0  -33.944923   18.668673
# std              3.275336     0.0    0.217793    0.568946
# min              0.000000  2017.0  -34.589721   18.329108
# 25%              8.000000  2017.0  -34.037828   18.457490
# 50%              9.000000  2017.0  -33.950865   18.505041
# 75%             10.000000  2017.0  -33.908311   18.638249
# max             13.000000  2017.0  -32.705958   22.192635

# %%
map_osm = folium.Map(location=[-33.925, 18.625], zoom_start=10)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff13143a7ef42e7c753d598d8b0bb619 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff13143a7ef42e7c753d598d8b0bb619&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff13143a7ef42e7c753d598d8b0bb619 = L.map(
#                 &quot;map_ff13143a7ef42e7c753d598d8b0bb619&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e175817cfd03e9cfd2cfa6d1363dc87 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_dark = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6525bc11dac17670975f0ce84c0167d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6525bc11dac17670975f0ce84c0167d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6525bc11dac17670975f0ce84c0167d = L.map(
#                 &quot;map_c6525bc11dac17670975f0ce84c0167d&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2499e1846fd738326a5aa48ce8480485 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c6525bc11dac17670975f0ce84c0167d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_suburbs_locations = df_suburbs[['Latitude', 'Longitude']]
#df_suburbs_locations
suburbs_location_list = df_suburbs_locations.values.tolist()
suburbs_location_list_size = len(suburbs_location_list)
suburbs_location_list_size
# Out:
# 121

# %%
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point]).add_to(map_osm)
    folium.Marker(suburbs_location_list[point]).add_to(map_dark)
    
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff13143a7ef42e7c753d598d8b0bb619 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff13143a7ef42e7c753d598d8b0bb619&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff13143a7ef42e7c753d598d8b0bb619 = L.map(
#                 &quot;map_ff13143a7ef42e7c753d598d8b0bb619&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e175817cfd03e9cfd2cfa6d1363dc87 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_c32ac432c4dfaeb375a4d807ffc08227 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_a06dd9dcece7915d325a1d5e297ed852 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_35b9653d22394df8f864ea33f0274372 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_2ac82c72642808c75a579ea917cd123f = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_7de04142ad13954a04147dd619384731 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_d2945ef26fbc9510d6ab0d6ce54ead62 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_dbdc70cda57f46587ccd6b07bee1e0f3 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_245315870ccdae5d8e6c84026729b523 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_69795c8638070e06886570756d85fbde = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_58af7bb577d352001a03bbe14fa69159 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_eced7edfdee1e520e73d8eff3c1b117b = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker_f23064251c96d6e5686786a5410ee6f3 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_ff13143a7ef42e7c753d598d8b0bb619);
#
#
#             var marker
&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_653a57bb081c0e2a4f8024831d8cca52 = L.map(
#                 &quot;map_653a57bb081c0e2a4f8024831d8cca52&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f31001317be3f67265e7f15601fd0e1d = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_653a57bb081c0e2a4f8024831d8cca52);
#
#
#             var circle_2acc07b10a6ea4980fb3b4d8072545d2 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_653a57bb081c0e2a4f8024831d8cca52);
#
#
#         var popup_56454a996cb5e1a336ed80e24bcbcad3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40f1dce46c66691d33a75a58157209e7 = $(`&lt;div id=&quot;html_40f1dce46c66691d33a75a58157209e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_56454a996cb5e1a336ed80e24bcbcad3.setContent(html_40f1dce46c66691d33a75a58157209e7);
#
#
#
#         circle_2acc07b10a6ea4980fb3b4d8072545d2.bindPopup(popup_56454a996cb5e1a336ed80e24bcbcad3)
#         ;
#
#
#
#
#             var circle_12d8798bdd2e6df6dbda9ca3af8052fd = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_653a57bb081c0e2a4f8024831d8cca52);
#
#
#         var popup_32a25e8eadd72a6c95aeefca23034248 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b09ca4c077958e506c5ce4f20e4ea342 = $(`&lt;div id=&quot;html_b09ca4c077958e506c5ce4f20e4ea342&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_32a25e8eadd72a6c95aeefca23034248.setContent(html_b09ca4c077958e506c5ce4f20e4ea342);
#
#
#
#         circle_12d8798bdd2e6df6dbda9ca3af8052fd.bindPopup(popup_32a25e8eadd72a6c95aeefca23034248)
#         ;
#
#
#
#
#             var circle_6af26c096caaa21d02860c9679c2dff3 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_653a57bb081c0e2a4f8024831d8cca52);
#
#
#         var popup_f834597616788e47c9da0c9080175908 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2af07734ee4d5d8e720acfbb196ec37 = $(`&lt;div id=&quot;html_d2af07734ee4d5d8e720acfbb196ec37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_f834597616788e47c9da0c9080175908.setContent(html_d2af07734ee4d5d8e720acfbb196ec37);
#
#
#
#         circle_6af26c096caaa21d02860c9679c2dff3.bindPopup(popup_f834597616788e47c9da0c9080175908)
#         ;
#
#
#
#
#             var circle_2d0e85330c51366f4fac9fb644159315 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &

# %%
# Adding Classification
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    # Classify by usage
    if df_suburbs['Oct 2017\nkl/month'][point] <= 8 and df_suburbs['Oct 2017\nkl/month'][point] > 0:
        usage_color = 'green'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 8 and df_suburbs['Oct 2017\nkl/month'][point] <= 10:
        usage_color = '#17cbef'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 10:
        usage_color = 'red'
    else: # Outliers
        usage_color = 'orange'
        
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color=usage_color,
        fill=True,
        opacity=0.8,
        fill_color=usage_color,
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_780f59a21a2a72b922ba9e1e9629c704 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_780f59a21a2a72b922ba9e1e9629c704&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_780f59a21a2a72b922ba9e1e9629c704 = L.map(
#                 &quot;map_780f59a21a2a72b922ba9e1e9629c704&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98e368baae3448b49e1eed6e623a17c7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_780f59a21a2a72b922ba9e1e9629c704);
#
#
#             var circle_6e15fea5952bcb3acad331a074d7b2da = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_780f59a21a2a72b922ba9e1e9629c704);
#
#
#         var popup_9de689d94a992bfe0c98c1baf80a2abc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5acc76d76736d98fc9645f970337b142 = $(`&lt;div id=&quot;html_5acc76d76736d98fc9645f970337b142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_9de689d94a992bfe0c98c1baf80a2abc.setContent(html_5acc76d76736d98fc9645f970337b142);
#
#
#
#         circle_6e15fea5952bcb3acad331a074d7b2da.bindPopup(popup_9de689d94a992bfe0c98c1baf80a2abc)
#         ;
#
#
#
#
#             var circle_96441e14bf93d7f9e1f223d06311dbe1 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_780f59a21a2a72b922ba9e1e9629c704);
#
#
#         var popup_9530c389639f0d5d728797158a831259 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e76aedc999b6d6f8360f44a34914bb25 = $(`&lt;div id=&quot;html_e76aedc999b6d6f8360f44a34914bb25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_9530c389639f0d5d728797158a831259.setContent(html_e76aedc999b6d6f8360f44a34914bb25);
#
#
#
#         circle_96441e14bf93d7f9e1f223d06311dbe1.bindPopup(popup_9530c389639f0d5d728797158a831259)
#         ;
#
#
#
#
#             var circle_de04e63b63c33317533260954e75d904 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_780f59a21a2a72b922ba9e1e9629c704);
#
#
#         var popup_908e13e8569ac4d2580e131a6e96d1d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1ead2bfdd16023fa0bb487b5731798b = $(`&lt;div id=&quot;html_d1ead2bfdd16023fa0bb487b5731798b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_908e13e8569ac4d2580e131a6e96d1d3.setContent(html_d1ead2bfdd16023fa0bb487b5731798b);
#
#
#
#         circle_de04e63b63c33317533260954e75d904.bindPopup(popup_908e13e8569ac4d2580e131a6e96d1d3)
#         ;
#
#
#
#
#             var circle_19a5b46442610c2826d494377b9403c9 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru

# %%
# Building choropleth map

df_world_countries = pd.read_json('world-countries.json')
df_unemployment = pd.read_csv('unemployment.csv', skiprows=4, delimiter=',')

df_unemployment
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 1    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 2    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 3    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 4    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# ..                                                 ...             ...   ...
# 259  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 260  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 261  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 262  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 263  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010   2011    2012    2013  \
# 0     NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# 1     NaN   NaN   NaN   NaN   NaN  ...   7.821000   8.23   7.936   8.452
# 2     NaN   NaN   NaN   NaN   NaN  ...   9.863000   7.36   7.347   7.331
# 3     NaN   NaN   NaN   NaN   NaN  ...  14.200000  13.98  13.440  15.640
# 4     NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# ..    ...   ...   ...   ...   ...  ...        ...    ...     ...     ...
# 259   NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# 260   NaN   NaN   NaN   NaN   NaN  ...  17.820000  16.99  15.277  14.163
# 261   NaN   NaN   NaN   NaN   NaN  ...  24.690001  24.65  24.730  24.570
# 262   NaN   NaN   NaN   NaN   NaN  ...  13.190000   9.99   7.850   7.816
# 263   NaN   NaN   NaN   NaN   NaN  ...   5.272000   5.37   5.328   5.205
#
#        2014    2015       2016    2017       2018  Unnamed: 63
# 0       NaN     NaN        NaN     NaN        NaN          NaN
# 1     8.706   8.864   8.841000   8.837   8.808000          NaN
# 2     7.306   7.281   7.724000   8.167   8.543000          NaN
# 3    17.490  17.080  15.220000  13.867  15.132000          NaN
# 4       NaN     NaN        NaN     NaN        NaN          NaN
# ..      ...     ...        ...     ...        ...          ...
# 259     NaN     NaN        NaN     NaN        NaN          NaN
# 260  13.470  13.807  13.729000  14.036  14.167000          NaN
# 261  24.900  25.160  26.549999  27.330  27.372999          NaN
# 262   7.783   7.750   7.777000   7.792   7.797000          NaN
# 263   5.135   5.086   5.046000   5.011   4.985000          NaN
#
# [264 rows x 64 columns]

# %%
df_unemployment_2018 = df_unemployment[['Country Name', 'Country Code', '2018']]
df_unemployment_2018.head(10)
# Out:
#            Country Name Country Code       2018
# 0                 Aruba          ABW        NaN
# 1           Afghanistan          AFG   8.808000
# 2                Angola          AGO   8.543000
# 3               Albania          ALB  15.132000
# 4               Andorra          AND        NaN
# 5            Arab World          ARB   9.808109
# 6  United Arab Emirates          ARE   1.710000
# 7             Argentina          ARG   8.162000
# 8               Armenia          ARM  18.275999
# 9        American Samoa          ASM        NaN

# %%
# Remove nulls

df_unemployment_2018_clean = df_unemployment_2018.dropna()
df_unemployment_2018_clean.head(10)
# Out:
#             Country Name Country Code       2018
# 1            Afghanistan          AFG   8.808000
# 2                 Angola          AGO   8.543000
# 3                Albania          ALB  15.132000
# 5             Arab World          ARB   9.808109
# 6   United Arab Emirates          ARE   1.710000
# 7              Argentina          ARG   8.162000
# 8                Armenia          ARM  18.275999
# 11             Australia          AUS   5.474000
# 12               Austria          AUT   5.387000
# 13            Azerbaijan          AZE   5.037000

# %%
df_unemployment_2018_clean.shape
# Out:
# (233, 3)

# %%
# prepare data for our map
legendTitle = 'Unemployment rate per country 2018 (%)'

# Data to plot country code and value
data_unemployment = df_unemployment_2018_clean[['Country Code', '2018']]

data_unemployment.head()
# Out:
#   Country Code       2018
# 1          AFG   8.808000
# 2          AGO   8.543000
# 3          ALB  15.132000
# 5          ARB   9.808109
# 6          ARE   1.710000

# %%
# Setup the map
map_unemployment = folium.Map(location=[8.7832, 34.5085], zoom_start=3)

map_unemployment.choropleth(geo_data='world-countries.json',
                           data=data_unemployment,
                           columns=['Country Code', '2018'],
                           key_on='feature.id',
                           fill_color='YlOrRd',
                           fill_opacity=0.7,
                           line_opacity=0.2,
                           legend_name=legendTitle)

map_unemployment
# Out:
# /Users/esuabomdijemeni/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/folium/folium.py:411: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12d18219d7d3ea25b8bc8a58b0511b48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12d18219d7d3ea25b8bc8a58b0511b48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12d18219d7d3ea25b8bc8a58b0511b48 = L.map(
#                 &quot;map_12d18219d7d3ea25b8bc8a58b0511b48&quot;,
#                 {
#                     center: [8.7832, 34.5085],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0b135d0074d26f1e0c0b1001b292373 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_12d18219d7d3ea25b8bc8a58b0511b48);
#
#
#             var choropleth_9f2d188cac2e23d9d8794849c4bc8c51 = L.featureGroup(
#                 {}
#             ).addTo(map_12d18219d7d3ea25b8bc8a58b0511b48);
#
#
#         function geo_json_eee15289d6d2b69d7161514d08784b4f_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Afghanistan&quot;: case &quot;Angola&quot;: case &quot;Argentina&quot;: case &quot;Australia&quot;: case &quot;Austria&quot;: case &quot;Azerbaijan&quot;: case &quot;Belgium&quot;: case &quot;Burkina Faso&quot;: case &quot;Bulgaria&quot;: case &quot;Belize&quot;: case &quot;Brunei&quot;: case &quot;Central African Republic&quot;: case &quot;Canada&quot;: case &quot;Chile&quot;: case &quot;Colombia&quot;: case &quot;Costa Rica&quot;: case &quot;Djibouti&quot;: case &quot;Denmark&quot;: case &quot;Dominican Republic&quot;: case &quot;Eritrea&quot;: case &quot;Estonia&quot;: case &quot;Ethiopia&quot;: case &quot;Finland&quot;: case &quot;Fiji&quot;: case &quot;France&quot;: case &quot;Gambia&quot;: case &quot;Guinea Bissau&quot;: case &quot;Equatorial Guinea&quot;: case &quot;Croatia&quot;: case &quot;Ireland&quot;: case &quot;Iraq&quot;: case &quot;Kazakhstan&quot;: case &quot;Kyrgyzstan&quot;: case &quot;Lebanon&quot;: case &quot;Lithuania&quot;: case &quot;Luxembourg&quot;: case &quot;Latvia&quot;: case &quot;Morocco&quot;: case &quot;Mali&quot;: case &quot;Mongolia&quot;: case &quot;Malawi&quot;: case &quot;Nigeria&quot;: case &quot;New Zealand&quot;: case &quot;Portugal&quot;: case &quot;Russia&quot;: case &quot;Saudi Arabia&quot;: case &quot;Somalia&quot;: case &quot;Suriname&quot;: case &quot;Slovakia&quot;: case &quot;Slovenia&quot;: case &quot;Sweden&quot;: case &quot;Chad&quot;: case &quot;Trinidad and Tobago&quot;: case &quot;Ukraine&quot;: case &quot;Uruguay&quot;: case &quot;Uzbekistan&quot;: case &quot;Venezuela&quot;: case &quot;Vanuatu&quot;: case &quot;Zambia&quot;: case &quot;Zimbabwe&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Albania&quot;: case &quot;Armenia&quot;: case &quot;Botswana&quot;: case &quot;Spain&quot;: case &quot;Jordan&quot;: case &quot;Libya&quot;: case &quot;Montenegro&quot;: case &quot;New Caledonia&quot;: case &quot;Syria&quot;: case &quot;Tunisia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Antarctica&quot;: case &quot;French Southern and Antarctic Lands&quot;: case &quot;Northern Cyprus&quot;: case &quot;Falkland Islands&quot;: case &quot;Greenland&quot;: case &quot;Kosovo&quot;: case &quot;Western Sahara&quot;: case &quot;South Sudan&quot;: case &quot;Somaliland&quot;: case &quot;Taiwan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;The Bahamas&quot;: case &quot;Brazil&quot;: case &quot;Republic of the Congo&quot;: case &quot;Cyprus&quot;: case &quot;Algeria&quot;: case &quot;Egypt&quot;: case &quot;Georgia&quot;: case &quot;Guyana&quot;: case &quot;Haiti&quot;: case &quot;Iran&quot;: case &quot;Italy&quot;: case &quot;Jamaica&quot;: case &quot;Kenya&quot;: case &quot;Mauritania&quot;: case &quot;Puerto Rico&quot;: case &quot;Sudan&quot;: case &quot;Republic of Serbia&quot;: case &quot;Tajikistan&quot;: case &quot;Turkey&quot;: case &quot;Yemen&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Bosnia and Herzegovina&quot;: case &quot;Lesotho&quot;: case &quot;Mozambique&quot;: case &quot;Swaziland&quot;: case &quot;West Bank&quot;: case &quot;South Africa&quot;:

# %%
# Measuring Boundries

df_damLevels = pd.read_csv('https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/master/DamLevels.txt', delimiter=',')

df_damLevels.head()
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras Dam-Lower        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras Dam-Upper        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
#
#    ThisWeek  LastWeek  LastYear
# 0      73.7      75.2      49.9
# 1      50.2      51.7      35.6
# 2      70.0      69.8      92.4
# 3      40.9      41.9      10.6
# 4      65.6      67.5      15.5

# %%
df_location = pd.read_csv('https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/master/damLocations.txt', delimiter=',')

df_location.head()
# Out:
#                    Dam   Latitude  Longitude
# 0       Berg River Dam -33.925000  19.060833
# 1  Steenbras Dam-Upper -34.166300  18.910000
# 2  Steenbras Dam-Lower -34.179722  18.876389
# 3  Theewaterskloof Dam -34.078100  19.289200
# 4         Voelvlei Dam -33.337500  19.033600

# %%
# Join the two dataframes on the dam field
df_damData = pd.merge(df_damLevels, df_location, on='Dam', how='left')

df_damData.head()
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras Dam-Lower        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras Dam-Upper        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
#
#    ThisWeek  LastWeek  LastYear   Latitude  Longitude
# 0      73.7      75.2      49.9 -33.925000  19.060833
# 1      50.2      51.7      35.6 -34.179722  18.876389
# 2      70.0      69.8      92.4 -34.166300  18.910000
# 3      40.9      41.9      10.6 -34.078100  19.289200
# 4      65.6      67.5      15.5 -33.337500  19.033600

# %%
# Prepare data to plot
df_dams_locations = df_damData[['Latitude', 'Longitude']]
dams_location_list = df_dams_locations.values.tolist()
dams_location_list_size = len(dams_location_list)
dams_location_list_size
# Out:
# 6

# %%
map_dams = folium.Map(location=[-33.925, 18.625], zoom_start=10)
for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_dams)
    
map_dams
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a824612e6b34dfd2778bd5405994a0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a824612e6b34dfd2778bd5405994a0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a824612e6b34dfd2778bd5405994a0c = L.map(
#                 &quot;map_7a824612e6b34dfd2778bd5405994a0c&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c97db17b0952bc946adfed1f8f333b04 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7a824612e6b34dfd2778bd5405994a0c);
#
#
#             var marker_73add1ef32fc18a900d14f8e0cdb3a8e = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_7a824612e6b34dfd2778bd5405994a0c);
#
#
#         var popup_76e7bda978d71344bbf28854e45bb276 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a153cc9d0cbc3abd49382fd60b0d53e = $(`&lt;div id=&quot;html_1a153cc9d0cbc3abd49382fd60b0d53e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_76e7bda978d71344bbf28854e45bb276.setContent(html_1a153cc9d0cbc3abd49382fd60b0d53e);
#
#
#
#         marker_73add1ef32fc18a900d14f8e0cdb3a8e.bindPopup(popup_76e7bda978d71344bbf28854e45bb276)
#         ;
#
#
#
#
#             var marker_c2091342d4ea7af0d0c6a3376986cccf = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_7a824612e6b34dfd2778bd5405994a0c);
#
#
#         var popup_6abc3dcd783115e1e7d58009fc732447 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f73b3db12784400ad451fe433288933e = $(`&lt;div id=&quot;html_f73b3db12784400ad451fe433288933e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_6abc3dcd783115e1e7d58009fc732447.setContent(html_f73b3db12784400ad451fe433288933e);
#
#
#
#         marker_c2091342d4ea7af0d0c6a3376986cccf.bindPopup(popup_6abc3dcd783115e1e7d58009fc732447)
#         ;
#
#
#
#
#             var marker_17e69554a3cad8ead7084e3459645006 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_7a824612e6b34dfd2778bd5405994a0c);
#
#
#         var popup_0842d18bf327f74ed29cd9be7552708e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0e85d9d8a8bed6e40d8e031a115446b = $(`&lt;div id=&quot;html_d0e85d9d8a8bed6e40d8e031a115446b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_0842d18bf327f74ed29cd9be7552708e.setContent(html_d0e85d9d8a8bed6e40d8e031a115446b);
#
#
#
#         marker_17e69554a3cad8ead7084e3459645006.bindPopup(popup_0842d18bf327f74ed29cd9be7552708e)
#         ;
#
#
#
#
#             var marker_7eedcb0cdaeffc9d8576af2800854468 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_7a824612e6b34dfd2778bd5405994a0c);
#
#
#         var popup_e0a628fcfbd59f6a4332df34fd5c88c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f9cb1edbd40efe67a603cdcb35ad605 = $(`&lt;div id=&quot;html_9f9cb1edbd40efe67a603cdcb35ad605&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_e0a628fcfbd59f6a4332df34fd5c88c7.setContent(html_9f9cb1edbd40efe67a603cdcb35ad605);
#
#
#
#         marker_7eedcb0cdaeffc9d8576af2800854468.bindPopup(popup_e0a628fcfbd59f6a4332df34fd5c88c7)
#         ;
#
#
#
#
#             var marker_23b0d9803f46fc9f1f00021b18cae350 = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_7a824612e6b34dfd2778bd5405994a0c);
#
#
#         var popup_3fd916cbbcb1f10edcef0caf66cf8b24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9cac59875550b5a73a62cbe0737da17b = $(`&lt;div id=&quot;html_9cac59875550b5a73a62cbe0737da17b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_3fd916cbbcb1f10edcef0caf66cf8b24.setContent(html_9cac59875550b5a73a62cbe0737da17b);
#
#
#
#         marker_23b0d9803f46fc9f1f00021b18cae350.bindPopup(popup_3fd916cbbcb1f10edcef0caf66cf8b24)
#         ;
#
#
#
#
#             var marker_adbaf62da208407c30904aafd2a1888c = L.marker(
#                 [-33.8336, 19.0889],
#                 {}
#             ).addTo(map_7a824612e6b34dfd2778bd5405994a0c);
#
#
#         var popup_d724ac64b183dcce3b1fc249f5ead6

# %%
map_url = folium.Map(location=[-34.078100, 19.289200],
                    tiles='http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                    zoom_start=12,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community')

for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_url)

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6062352003fcab0b5f000ac03c2009bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6062352003fcab0b5f000ac03c2009bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6062352003fcab0b5f000ac03c2009bd = L.map(
#                 &quot;map_6062352003fcab0b5f000ac03c2009bd&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2ec723898a3f66af8e0e1a5cb052164 = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#             var marker_ab7803d597359142b7c120ae2ccb46a7 = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_632335f28466dd73bd5c406fc882c96d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac4cf3ffa46a352c6bd0b4bacc8c058e = $(`&lt;div id=&quot;html_ac4cf3ffa46a352c6bd0b4bacc8c058e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_632335f28466dd73bd5c406fc882c96d.setContent(html_ac4cf3ffa46a352c6bd0b4bacc8c058e);
#
#
#
#         marker_ab7803d597359142b7c120ae2ccb46a7.bindPopup(popup_632335f28466dd73bd5c406fc882c96d)
#         ;
#
#
#
#
#             var marker_c385b7441b385f64f6f223441eff7780 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_4a84f82504cc99cd584fa4402d8c506f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02755b10e81059b917ed0078211122a6 = $(`&lt;div id=&quot;html_02755b10e81059b917ed0078211122a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_4a84f82504cc99cd584fa4402d8c506f.setContent(html_02755b10e81059b917ed0078211122a6);
#
#
#
#         marker_c385b7441b385f64f6f223441eff7780.bindPopup(popup_4a84f82504cc99cd584fa4402d8c506f)
#         ;
#
#
#
#
#             var marker_5ba5c10ab4203f248f4dc361786000ec = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_658fdedd2b2c9488292ba4fd07e1b732 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f652a57dcad6c201db58f09f976b4d5e = $(`&lt;div id=&quot;html_f652a57dcad6c201db58f09f976b4d5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_658fdedd2b2c9488292ba4fd07e1b732.setContent(html_f652a57dcad6c201db58f09f976b4d5e);
#
#
#
#         marker_5ba5c10ab4203f248f4dc361786000ec.bindPopup(popup_658fdedd2b2c9488292ba4fd07e1b732)
#         ;
#
#
#
#
#             var marker_c3a5382405e3243f3a4c3e18b1742592 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_76de80e056c72c91af5ed43ee81f48eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ff5b58cce619dfb2a8fb6717e03a8c6 = $(`&lt;div id=&quot;html_2ff5b58cce619dfb2a8fb6717e03a8c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_76de80e056c72c91af5ed43ee81f48eb.setContent(html_2ff5b58cce619dfb2a8fb6717e03a8c6);
#
#
#
#         marker_c3a5382405e3243f3a4c3e18b1742592.bindPopup(popup_76de80e056c72c91af5ed43ee81f48eb)
#         ;
#
#
#
#
#             var marker_b620b74cf245ff35ca63ee0e6864907f = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_446a99e522bf66a7ed2d5e32999bee08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94d556dfd2b3a11fa2e6ccb8eb18a1b0 = $(`&lt;div id=&quot;html_94d556dfd2b3a11fa2e6ccb8eb18a1b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_446a99e522bf66a7ed2d5e32999bee08.setContent(html_94d556dfd2b3a11fa2e6ccb8eb18a1b0);
#
#
#
#         marker_b620b74cf245ff35ca63ee0e6864907f.bindPopup(popup_446a99e522bf66a7ed2d5e32999bee08)
#         ;
#
#
#
#
#             var marker_18819a35a562a8e901d102afda6411e9 = L.marker(
#                 [-33.8336, 19.0889],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_4a2b760b0d858222da97ff4168cb34be =

# %%
from folium.plugins import MeasureControl

map_url.add_child(MeasureControl())

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6062352003fcab0b5f000ac03c2009bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6062352003fcab0b5f000ac03c2009bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6062352003fcab0b5f000ac03c2009bd = L.map(
#                 &quot;map_6062352003fcab0b5f000ac03c2009bd&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2ec723898a3f66af8e0e1a5cb052164 = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#             var marker_ab7803d597359142b7c120ae2ccb46a7 = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_632335f28466dd73bd5c406fc882c96d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac4cf3ffa46a352c6bd0b4bacc8c058e = $(`&lt;div id=&quot;html_ac4cf3ffa46a352c6bd0b4bacc8c058e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_632335f28466dd73bd5c406fc882c96d.setContent(html_ac4cf3ffa46a352c6bd0b4bacc8c058e);
#
#
#
#         marker_ab7803d597359142b7c120ae2ccb46a7.bindPopup(popup_632335f28466dd73bd5c406fc882c96d)
#         ;
#
#
#
#
#             var marker_c385b7441b385f64f6f223441eff7780 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_4a84f82504cc99cd584fa4402d8c506f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02755b10e81059b917ed0078211122a6 = $(`&lt;div id=&quot;html_02755b10e81059b917ed0078211122a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_4a84f82504cc99cd584fa4402d8c506f.setContent(html_02755b10e81059b917ed0078211122a6);
#
#
#
#         marker_c385b7441b385f64f6f223441eff7780.bindPopup(popup_4a84f82504cc99cd584fa4402d8c506f)
#         ;
#
#
#
#
#             var marker_5ba5c10ab4203f248f4dc361786000ec = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_658fdedd2b2c9488292ba4fd07e1b732 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f652a57dcad6c201db58f09f976b4d5e = $(`&lt;div id=&quot;html_f652a57dcad6c201db58f09f976b4d5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_658fdedd2b2c9488292ba4fd07e1b732.setContent(html_f652a57dcad6c201db58f09f976b4d5e);
#
#
#
#         marker_5ba5c10ab4203f248f4dc361786000ec.bindPopup(popup_658fdedd2b2c9488292ba4fd07e1b732)
#         ;
#
#
#
#
#             var marker_c3a5382405e3243f3a4c3e18b1742592 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_76de80e056c72c91af5ed43ee81f48eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ff5b58cce619dfb2a8fb6717e03a8c6 = $(`&lt;div id=&quot;html_2ff5b58cce619dfb2a8fb6717e03a8c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_76de80e056c72c91af5ed43ee81f48eb.setContent(html_2ff5b58cce619dfb2a8fb6717e03a8c6);
#
#
#
#         marker_c3a5382405e3243f3a4c3e18b1742592.bindPopup(popup_76de80e056c72c91af5ed43ee81f48eb)
#         ;
#
#
#
#
#             var marker_b620b74cf245ff35ca63ee0e6864907f = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_6062352003fcab0b5f000ac03c2009bd);
#
#
#         var popup_446a99e522bf66a7ed2d5e32999bee08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94d556dfd2b3a11fa2e6ccb8eb18a1b0 = $(`&lt;div id=&quot;html_94d556dfd2b3a11fa2e6ccb8eb18a1b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_446a99e522bf66a7ed2d5e32999bee08.setContent(html_94d556dfd2b3a11fa2e6ccb8eb18a1b0);
#
#
#
#         marker_b620b74cf245ff35ca63ee0e6864907f.bindPopup(popup_446a99e522bf66a7ed2d5e32999bee0

# %%
# Add Layer Control
map_layers = map_points

add = '/MapServer/tile/{z}/{y}/{x}'
ESRI = dict(World_Ocean_Base='http://services.arcgisonline.com/arcgis/rest/services/Ocean/World_Ocean_Base',
            World_Navigation_Charts='http://services.arcgisonline.com/ArcGIS/rest/services/Specialty/World_Navigation_Charts',
            NatGeo_World_Map='http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer',
            World_Imagery='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer',
            World_Physical_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Physical_Map/MapServer',
            World_Shaded_Relief='http://services.arcgisonline.com/arcgis/rest/services/World_Shaded_Relief/MapServer',
            World_Street_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Street_Map/MapServer',
            World_Terrain_Base='http://services.arcgisonline.com/arcgis/rest/services/World_Terrain_Base/MapServer',
            World_Topo_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Topo_Map/MapServer')


for tile_name, tile_url in ESRI.items():
    tile_url += add
    folium.TileLayer(tile_url,
                    name=tile_name,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community').add_to(map_points)
    

folium.LayerControl().add_to(map_layers)

map_layers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_780f59a21a2a72b922ba9e1e9629c704 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_780f59a21a2a72b922ba9e1e9629c704&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_780f59a21a2a72b922ba9e1e9629c704 = L.map(
#                 &quot;map_780f59a21a2a72b922ba9e1e9629c704&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98e368baae3448b49e1eed6e623a17c7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_780f59a21a2a72b922ba9e1e9629c704);
#
#
#             var circle_6e15fea5952bcb3acad331a074d7b2da = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_780f59a21a2a72b922ba9e1e9629c704);
#
#
#         var popup_9de689d94a992bfe0c98c1baf80a2abc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5acc76d76736d98fc9645f970337b142 = $(`&lt;div id=&quot;html_5acc76d76736d98fc9645f970337b142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_9de689d94a992bfe0c98c1baf80a2abc.setContent(html_5acc76d76736d98fc9645f970337b142);
#
#
#
#         circle_6e15fea5952bcb3acad331a074d7b2da.bindPopup(popup_9de689d94a992bfe0c98c1baf80a2abc)
#         ;
#
#
#
#
#             var circle_96441e14bf93d7f9e1f223d06311dbe1 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_780f59a21a2a72b922ba9e1e9629c704);
#
#
#         var popup_9530c389639f0d5d728797158a831259 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e76aedc999b6d6f8360f44a34914bb25 = $(`&lt;div id=&quot;html_e76aedc999b6d6f8360f44a34914bb25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_9530c389639f0d5d728797158a831259.setContent(html_e76aedc999b6d6f8360f44a34914bb25);
#
#
#
#         circle_96441e14bf93d7f9e1f223d06311dbe1.bindPopup(popup_9530c389639f0d5d728797158a831259)
#         ;
#
#
#
#
#             var circle_de04e63b63c33317533260954e75d904 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_780f59a21a2a72b922ba9e1e9629c704);
#
#
#         var popup_908e13e8569ac4d2580e131a6e96d1d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1ead2bfdd16023fa0bb487b5731798b = $(`&lt;div id=&quot;html_d1ead2bfdd16023fa0bb487b5731798b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_908e13e8569ac4d2580e131a6e96d1d3.setContent(html_d1ead2bfdd16023fa0bb487b5731798b);
#
#
#
#         circle_de04e63b63c33317533260954e75d904.bindPopup(popup_908e13e8569ac4d2580e131a6e96d1d3)
#         ;
#
#
#
#
#             var circle_19a5b46442610c2826d494377b9403c9 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru

# %%
# Creating Heatmap

from folium.plugins import HeatMap

# Create our point map object
map_heat = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius='15',
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_heat)
    
# convert to array format for our heatmap
suburbsArray = df_suburbs[['Latitude', 'Longitude']].values

# plot heatmap
map_heat.add_child(HeatMap(suburbsArray))

map_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09216bc768aa112a7a45ad1f0bf4e708 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09216bc768aa112a7a45ad1f0bf4e708&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09216bc768aa112a7a45ad1f0bf4e708 = L.map(
#                 &quot;map_09216bc768aa112a7a45ad1f0bf4e708&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09cf6d4db6937715fbe3599d5a18cbd7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_09216bc768aa112a7a45ad1f0bf4e708);
#
#
#             var circle_6888a63f526d4a4c2af1bcc6df3a4166 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_09216bc768aa112a7a45ad1f0bf4e708);
#
#
#         var popup_b4bb4011b8f71b84d156f186345d64e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0581d1aa5da81c6d1109cf00290f122d = $(`&lt;div id=&quot;html_0581d1aa5da81c6d1109cf00290f122d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_b4bb4011b8f71b84d156f186345d64e6.setContent(html_0581d1aa5da81c6d1109cf00290f122d);
#
#
#
#         circle_6888a63f526d4a4c2af1bcc6df3a4166.bindPopup(popup_b4bb4011b8f71b84d156f186345d64e6)
#         ;
#
#
#
#
#             var circle_3a2dab48cf66050c7dc4fd835192955a = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_09216bc768aa112a7a45ad1f0bf4e708);
#
#
#         var popup_9e514c3c8e048600341f602cc598e96b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f59b239698468535736c8b8fd369afcb = $(`&lt;div id=&quot;html_f59b239698468535736c8b8fd369afcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_9e514c3c8e048600341f602cc598e96b.setContent(html_f59b239698468535736c8b8fd369afcb);
#
#
#
#         circle_3a2dab48cf66050c7dc4fd835192955a.bindPopup(popup_9e514c3c8e048600341f602cc598e96b)
#         ;
#
#
#
#
#             var circle_7a5c2c1233315a761fdf81e04551b36a = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_09216bc768aa112a7a45ad1f0bf4e708);
#
#
#         var popup_1a6051f27e1327827ed7c27b01f4e809 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85fd4fa7dd6c322b5041f2ade1851b43 = $(`&lt;div id=&quot;html_85fd4fa7dd6c322b5041f2ade1851b43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_1a6051f27e1327827ed7c27b01f4e809.setContent(html_85fd4fa7dd6c322b5041f2ade1851b43);
#
#
#
#         circle_7a5c2c1233315a761fdf81e04551b36a.bindPopup(popup_1a6051f27e1327827ed7c27b01f4e809)
#         ;
#
#
#
#
#             var circle_cbdd816a3cf0ceb86efc6ec3e79aef30 = L.circle(
#                 [-33.920011, 18.642819],

# %%
# !pip install selenium

# %%
import os
import time
from selenium import webdriver
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/tl/q1c606q156xbmnyd03bvkf7r0000gn/T/ipykernel_10085/94547548.py in <module>
#       1 import os
#       2 import time
# ----> 3 from selenium import webdriver
#
# ModuleNotFoundError: No module named 'selenium'

# %%
delay = 5

heat = 'map_heat.html'
unemployment = 'map_unemployment.html'

def export_maps(map_file, map_image, map_obj):
    browser = webdriver.Chrome('C:\\Users\\Edwin\\Downloads\\chromedriver_win32\\chromedriver.exe')
    tmpUrl = 'file://{path}/{mapfile}'.format(path=os.getcwd(), mapfile=map_file)
    map_obj.save(map_file)
    browser.get(tmpUrl)
    time.sleep(delay)
    browser.save_screenshot(map_image)
    browser.quit()
    
export_maps(heat, 'map_heat.png', map_heat)

# %%
export_maps(unemployment, 'map_unemployment.png', map_unemployment)
