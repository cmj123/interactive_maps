# %%
import folium
import pandas as pd

# %%
df_suburbs = pd.read_excel('waterwatch_clean2.xlsx', sheet_name='Sheet1')

df_suburbs.head()
# Out:
#    Unnamed: 0           Suburb  \
# 0           0          ATHLONE
# 1           1           AURORA
# 2           2       BANTRY BAY
# 3           3  BELLVILLE SOUTH
# 4           4        BERGVLIET
#
#    Number of single-residential properties_number  Oct 2017\nkl/month  \
# 0                                            2272                  11
# 1                                             426                  10
# 2                                             248                  13
# 3                                            2041                  11
# 4                                            1488                   8
#
#      Month  Year   Latitude  Longitude
# 0  October  2017 -33.967220  18.502140
# 1  October  2017 -32.705958  18.485135
# 2  October  2017 -33.927953  18.382592
# 3  October  2017 -33.920011  18.642819
# 4  October  2017 -34.047464  18.452499

# %%
df_suburbs.columns
# Out:
# Index(['Unnamed: 0', 'Suburb',
#        'Number of single-residential properties_number', 'Oct 2017\nkl/month',
#        'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_suburbs.shape
# Out:
# (121, 8)

# %%
df_suburbs.describe()
# Out:
#        Unnamed: 0  Number of single-residential properties_number  \
# count  121.000000                                      121.000000
# mean    60.000000                                     1849.983471
# std     35.073732                                     2506.756526
# min      0.000000                                        0.000000
# 25%     30.000000                                      364.000000
# 50%     60.000000                                     1009.000000
# 75%     90.000000                                     2411.000000
# max    120.000000                                    20719.000000
#
#        Oct 2017\nkl/month    Year    Latitude   Longitude
# count          121.000000   121.0  121.000000  121.000000
# mean             8.413223  2017.0  -33.944923   18.668673
# std              3.275336     0.0    0.217793    0.568946
# min              0.000000  2017.0  -34.589721   18.329108
# 25%              8.000000  2017.0  -34.037828   18.457490
# 50%              9.000000  2017.0  -33.950865   18.505041
# 75%             10.000000  2017.0  -33.908311   18.638249
# max             13.000000  2017.0  -32.705958   22.192635

# %%
map_osm = folium.Map(location=[-33.925, 18.625], zoom_start=10)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c57c7160cfe0bc836eb2df97f9d33fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c57c7160cfe0bc836eb2df97f9d33fd = L.map(
#                 &quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eb32f2af3ceae82ac5511edb1bf6830 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_dark = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8781d0ac9c061641eb96e87dbe7e462e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8781d0ac9c061641eb96e87dbe7e462e = L.map(
#                 &quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8da8c1f7d5f26711e5ff9801c70c91df = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_suburbs_locations = df_suburbs[['Latitude', 'Longitude']]
#df_suburbs_locations
suburbs_location_list = df_suburbs_locations.values.tolist()
suburbs_location_list_size = len(suburbs_location_list)
suburbs_location_list_size
# Out:
# 121

# %%
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point]).add_to(map_osm)
    folium.Marker(suburbs_location_list[point]).add_to(map_dark)
    
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c57c7160cfe0bc836eb2df97f9d33fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c57c7160cfe0bc836eb2df97f9d33fd = L.map(
#                 &quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eb32f2af3ceae82ac5511edb1bf6830 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_120603d8151b0e7727e64552437d14a5 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_bc3f483ea1138888f21283fe24f03583 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_69089978d0a7d63b63df8f94d23c5ae5 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_7a70545799e83b48e60354aaac7203b7 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_960ab05d7c9c82c52afa80ccf8a99862 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_fb0cc1616f289cd62d296ff9a8e5fcfa = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_d6a0687bad7e4cb0c74eef1e665a17a9 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_a2671bd468f4798581979d100fad6692 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_b8f54d5b710d5a8395f34540e903fb1b = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_c962e3e282e93c3ec09ca149c77f8930 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_9e55d211b616e4034b3b85d53a7ee861 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_12e914193adec9918262e6d4c8473c0a = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_0c011d88393a34139d5ebb9ba3f6c289 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_691a0daca1f6e8ee20e69acb24f5707d = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_490e2dfd38f3495ebb555c08a2f63f79 = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_3709d24687368f4c57cbc39fda99ac8c = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_b79c710656c95fea158653a56e4b98d7 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_ee5c52b55221e95f3dbf1232b83ace50 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_2421dfc0341183138bdd6b0094b3ebee = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_7e36d4ebb3f9b24b7971b810512b9906 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_bbaaa165b77ef8c6ba63c3533f9d2c14 = L.marker(
#                 [-33.841588, 18.651795],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8781d0ac9c061641eb96e87dbe7e462e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8781d0ac9c061641eb96e87dbe7e462e = L.map(
#                 &quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8da8c1f7d5f26711e5ff9801c70c91df = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_17ef4c2ad032bcaaa39ce3682def6729 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_7a3ed0f46a774ad44513e9564fe80b8f = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_a5839b95809a7e02d91a2f1c14e2026c = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_24422ee9ab541e68c9ad468c0a78a294 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_cdab2cfca236b466f779ab3faf2d0caa = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b908b6b6e3dc888dcada9bdecc5304b8 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_71fc93f816c379665efdc83a2ee9435b = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_f1cdec27bf5386b2d9e64d9aa7f3b926 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b7e585f02e5554b5ced0a260e3bf3e59 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_64f71c58f37d3268ffe9e633395918bf = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_31aaf2b9b1b316c3ab392f6ca5d90735 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b646d611c809b919a1f8f794da018241 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_84e153bff750e5c2d84e52e0d216f24c = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_fb19d71b4a471cf6cb113c5c407b9b88 = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_389fc2dfd02be8286171d209121d043e = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_bf830dbd324b9d8c008c4fe860c91bcd = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_1c7dc7732ff28062d312ea84031aa3c5 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_30a4f1f88193525f319622392466465f = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_a4a703a6b3c89496ee469887da65d247 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_649c86022f3957e9bda6d6bd51705f35 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_180117f28023f24c1052b338222c3539 =

# %%
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point]).add_to(map_osm)
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point]).add_to(map_dark)
    
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c57c7160cfe0bc836eb2df97f9d33fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c57c7160cfe0bc836eb2df97f9d33fd = L.map(
#                 &quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eb32f2af3ceae82ac5511edb1bf6830 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_120603d8151b0e7727e64552437d14a5 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_bc3f483ea1138888f21283fe24f03583 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_69089978d0a7d63b63df8f94d23c5ae5 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_7a70545799e83b48e60354aaac7203b7 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_960ab05d7c9c82c52afa80ccf8a99862 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_fb0cc1616f289cd62d296ff9a8e5fcfa = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_d6a0687bad7e4cb0c74eef1e665a17a9 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_a2671bd468f4798581979d100fad6692 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_b8f54d5b710d5a8395f34540e903fb1b = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_c962e3e282e93c3ec09ca149c77f8930 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_9e55d211b616e4034b3b85d53a7ee861 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_12e914193adec9918262e6d4c8473c0a = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_0c011d88393a34139d5ebb9ba3f6c289 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_691a0daca1f6e8ee20e69acb24f5707d = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_490e2dfd38f3495ebb555c08a2f63f79 = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_3709d24687368f4c57cbc39fda99ac8c = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_b79c710656c95fea158653a56e4b98d7 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_ee5c52b55221e95f3dbf1232b83ace50 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_2421dfc0341183138bdd6b0094b3ebee = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_7e36d4ebb3f9b24b7971b810512b9906 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_bbaaa165b77ef8c6ba63c3533f9d2c14 = L.marker(
#                 [-33.841588, 18.651795],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8781d0ac9c061641eb96e87dbe7e462e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8781d0ac9c061641eb96e87dbe7e462e = L.map(
#                 &quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8da8c1f7d5f26711e5ff9801c70c91df = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_17ef4c2ad032bcaaa39ce3682def6729 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_7a3ed0f46a774ad44513e9564fe80b8f = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_a5839b95809a7e02d91a2f1c14e2026c = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_24422ee9ab541e68c9ad468c0a78a294 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_cdab2cfca236b466f779ab3faf2d0caa = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b908b6b6e3dc888dcada9bdecc5304b8 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_71fc93f816c379665efdc83a2ee9435b = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_f1cdec27bf5386b2d9e64d9aa7f3b926 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b7e585f02e5554b5ced0a260e3bf3e59 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_64f71c58f37d3268ffe9e633395918bf = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_31aaf2b9b1b316c3ab392f6ca5d90735 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b646d611c809b919a1f8f794da018241 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_84e153bff750e5c2d84e52e0d216f24c = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_fb19d71b4a471cf6cb113c5c407b9b88 = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_389fc2dfd02be8286171d209121d043e = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_bf830dbd324b9d8c008c4fe860c91bcd = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_1c7dc7732ff28062d312ea84031aa3c5 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_30a4f1f88193525f319622392466465f = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_a4a703a6b3c89496ee469887da65d247 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_649c86022f3957e9bda6d6bd51705f35 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_180117f28023f24c1052b338222c3539 =

# %%
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point], icon=folium.Icon(color='darkblue', icon_color='white', icon='tint', angle=0, prefix='fa')).add_to(map_osm)
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point], icon=folium.Icon(color='darkblue', icon_color='white', icon='tint', angle=0, prefix='fa')).add_to(map_dark)
    
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c57c7160cfe0bc836eb2df97f9d33fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c57c7160cfe0bc836eb2df97f9d33fd = L.map(
#                 &quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eb32f2af3ceae82ac5511edb1bf6830 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_120603d8151b0e7727e64552437d14a5 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_bc3f483ea1138888f21283fe24f03583 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_69089978d0a7d63b63df8f94d23c5ae5 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_7a70545799e83b48e60354aaac7203b7 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_960ab05d7c9c82c52afa80ccf8a99862 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_fb0cc1616f289cd62d296ff9a8e5fcfa = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_d6a0687bad7e4cb0c74eef1e665a17a9 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_a2671bd468f4798581979d100fad6692 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_b8f54d5b710d5a8395f34540e903fb1b = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_c962e3e282e93c3ec09ca149c77f8930 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_9e55d211b616e4034b3b85d53a7ee861 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_12e914193adec9918262e6d4c8473c0a = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_0c011d88393a34139d5ebb9ba3f6c289 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_691a0daca1f6e8ee20e69acb24f5707d = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_490e2dfd38f3495ebb555c08a2f63f79 = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_3709d24687368f4c57cbc39fda99ac8c = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_b79c710656c95fea158653a56e4b98d7 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_ee5c52b55221e95f3dbf1232b83ace50 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_2421dfc0341183138bdd6b0094b3ebee = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_7e36d4ebb3f9b24b7971b810512b9906 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_bbaaa165b77ef8c6ba63c3533f9d2c14 = L.marker(
#                 [-33.841588, 18.651795],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8781d0ac9c061641eb96e87dbe7e462e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8781d0ac9c061641eb96e87dbe7e462e = L.map(
#                 &quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8da8c1f7d5f26711e5ff9801c70c91df = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_17ef4c2ad032bcaaa39ce3682def6729 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_7a3ed0f46a774ad44513e9564fe80b8f = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_a5839b95809a7e02d91a2f1c14e2026c = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_24422ee9ab541e68c9ad468c0a78a294 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_cdab2cfca236b466f779ab3faf2d0caa = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b908b6b6e3dc888dcada9bdecc5304b8 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_71fc93f816c379665efdc83a2ee9435b = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_f1cdec27bf5386b2d9e64d9aa7f3b926 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b7e585f02e5554b5ced0a260e3bf3e59 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_64f71c58f37d3268ffe9e633395918bf = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_31aaf2b9b1b316c3ab392f6ca5d90735 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b646d611c809b919a1f8f794da018241 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_84e153bff750e5c2d84e52e0d216f24c = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_fb19d71b4a471cf6cb113c5c407b9b88 = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_389fc2dfd02be8286171d209121d043e = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_bf830dbd324b9d8c008c4fe860c91bcd = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_1c7dc7732ff28062d312ea84031aa3c5 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_30a4f1f88193525f319622392466465f = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_a4a703a6b3c89496ee469887da65d247 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_649c86022f3957e9bda6d6bd51705f35 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_180117f28023f24c1052b338222c3539 =

# %%
# Classification
for point in range(0, suburbs_location_list_size):
    if df_suburbs['Oct 2017\nkl/month'][point] < 5:
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='green', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_osm)
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='green', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_dark)
    elif df_suburbs['Oct 2017\nkl/month'][point] > 5 and df_suburbs['Oct 2017\nkl/month'][point] <= 8:
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='blue', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_osm)
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='blue', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_dark)
        
    else:
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='red', icon_color='white', icon='thumbs-down', angle=0, prefix='fa')).add_to(map_osm)
        folium.Marker(suburbs_location_list[point], 
                      popup=df_suburbs['Suburb'][point], 
                      icon=folium.Icon(color='red', icon_color='white', icon='thumbs-down', angle=0, prefix='fa')).add_to(map_dark)
        

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c57c7160cfe0bc836eb2df97f9d33fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c57c7160cfe0bc836eb2df97f9d33fd = L.map(
#                 &quot;map_2c57c7160cfe0bc836eb2df97f9d33fd&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eb32f2af3ceae82ac5511edb1bf6830 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_120603d8151b0e7727e64552437d14a5 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_bc3f483ea1138888f21283fe24f03583 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_69089978d0a7d63b63df8f94d23c5ae5 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_7a70545799e83b48e60354aaac7203b7 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_960ab05d7c9c82c52afa80ccf8a99862 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_fb0cc1616f289cd62d296ff9a8e5fcfa = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_d6a0687bad7e4cb0c74eef1e665a17a9 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_a2671bd468f4798581979d100fad6692 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_b8f54d5b710d5a8395f34540e903fb1b = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_c962e3e282e93c3ec09ca149c77f8930 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_9e55d211b616e4034b3b85d53a7ee861 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_12e914193adec9918262e6d4c8473c0a = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_0c011d88393a34139d5ebb9ba3f6c289 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_691a0daca1f6e8ee20e69acb24f5707d = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_490e2dfd38f3495ebb555c08a2f63f79 = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_3709d24687368f4c57cbc39fda99ac8c = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_b79c710656c95fea158653a56e4b98d7 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_ee5c52b55221e95f3dbf1232b83ace50 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_2421dfc0341183138bdd6b0094b3ebee = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_7e36d4ebb3f9b24b7971b810512b9906 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);
#
#
#             var marker_bbaaa165b77ef8c6ba63c3533f9d2c14 = L.marker(
#                 [-33.841588, 18.651795],
#                 {}
#             ).addTo(map_2c57c7160cfe0bc836eb2df97f9d33fd);

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8781d0ac9c061641eb96e87dbe7e462e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8781d0ac9c061641eb96e87dbe7e462e = L.map(
#                 &quot;map_8781d0ac9c061641eb96e87dbe7e462e&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8da8c1f7d5f26711e5ff9801c70c91df = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_17ef4c2ad032bcaaa39ce3682def6729 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_7a3ed0f46a774ad44513e9564fe80b8f = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_a5839b95809a7e02d91a2f1c14e2026c = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_24422ee9ab541e68c9ad468c0a78a294 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_cdab2cfca236b466f779ab3faf2d0caa = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b908b6b6e3dc888dcada9bdecc5304b8 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_71fc93f816c379665efdc83a2ee9435b = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_f1cdec27bf5386b2d9e64d9aa7f3b926 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b7e585f02e5554b5ced0a260e3bf3e59 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_64f71c58f37d3268ffe9e633395918bf = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_31aaf2b9b1b316c3ab392f6ca5d90735 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_b646d611c809b919a1f8f794da018241 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_84e153bff750e5c2d84e52e0d216f24c = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_fb19d71b4a471cf6cb113c5c407b9b88 = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_389fc2dfd02be8286171d209121d043e = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_bf830dbd324b9d8c008c4fe860c91bcd = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_1c7dc7732ff28062d312ea84031aa3c5 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_30a4f1f88193525f319622392466465f = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_a4a703a6b3c89496ee469887da65d247 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_649c86022f3957e9bda6d6bd51705f35 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_8781d0ac9c061641eb96e87dbe7e462e);
#
#
#             var marker_180117f28023f24c1052b338222c3539 =

# %%
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_590862c0f76cd06e5d85bd3c05314646 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_590862c0f76cd06e5d85bd3c05314646&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_590862c0f76cd06e5d85bd3c05314646 = L.map(
#                 &quot;map_590862c0f76cd06e5d85bd3c05314646&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_576066082dcb4e4fd4793c714b0e815e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_590862c0f76cd06e5d85bd3c05314646);
#
#
#             var circle_0de59eb1353f529a56d4e6708ffb0e45 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_590862c0f76cd06e5d85bd3c05314646);
#
#
#         var popup_3b38d1f78dfdbdae68d47ec72e28af39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a203f61adfb2658a0019b16951280592 = $(`&lt;div id=&quot;html_a203f61adfb2658a0019b16951280592&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_3b38d1f78dfdbdae68d47ec72e28af39.setContent(html_a203f61adfb2658a0019b16951280592);
#
#
#
#         circle_0de59eb1353f529a56d4e6708ffb0e45.bindPopup(popup_3b38d1f78dfdbdae68d47ec72e28af39)
#         ;
#
#
#
#
#             var circle_eb4dbfa375a2632b41cf6be545c07355 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_590862c0f76cd06e5d85bd3c05314646);
#
#
#         var popup_40f3a08aa35a5b78cbd4da3595e3a45f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb3ae6728f01d6aa4cc804511ac6e468 = $(`&lt;div id=&quot;html_fb3ae6728f01d6aa4cc804511ac6e468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_40f3a08aa35a5b78cbd4da3595e3a45f.setContent(html_fb3ae6728f01d6aa4cc804511ac6e468);
#
#
#
#         circle_eb4dbfa375a2632b41cf6be545c07355.bindPopup(popup_40f3a08aa35a5b78cbd4da3595e3a45f)
#         ;
#
#
#
#
#             var circle_20fccf836a6b40cadb83f424753d97fb = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_590862c0f76cd06e5d85bd3c05314646);
#
#
#         var popup_27b924214ee6b3f24e77123c96262ed6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d42f64b82abf25967441c1215eff5b7 = $(`&lt;div id=&quot;html_9d42f64b82abf25967441c1215eff5b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_27b924214ee6b3f24e77123c96262ed6.setContent(html_9d42f64b82abf25967441c1215eff5b7);
#
#
#
#         circle_20fccf836a6b40cadb83f424753d97fb.bindPopup(popup_27b924214ee6b3f24e77123c96262ed6)
#         ;
#
#
#
#
#             var circle_04e7c69e19b312c56ebb8f1cf5f2b96e = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &

# %%
# Adding Classification
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    # Classify by usage
    if df_suburbs['Oct 2017\nkl/month'][point] <= 8 and df_suburbs['Oct 2017\nkl/month'][point] > 0:
        usage_color = 'green'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 8 and df_suburbs['Oct 2017\nkl/month'][point] <= 10:
        usage_color = '#17cbef'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 10:
        usage_color = 'red'
    else: # Outliers
        usage_color = 'orange'
        
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color=usage_color,
        fill=True,
        opacity=0.8,
        fill_color=usage_color,
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4b57b6ff951cbd3c5296be773de1280 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4b57b6ff951cbd3c5296be773de1280&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4b57b6ff951cbd3c5296be773de1280 = L.map(
#                 &quot;map_d4b57b6ff951cbd3c5296be773de1280&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac9ed37ccaa503c7769f260e5d768816 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d4b57b6ff951cbd3c5296be773de1280);
#
#
#             var circle_6ef228ce9c1e5c311d3aeff73d761f20 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d4b57b6ff951cbd3c5296be773de1280);
#
#
#         var popup_6dbc55718bd746a0ddadf212a31ebb0c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bcaa92a81e7d934eef7fd3c76b401915 = $(`&lt;div id=&quot;html_bcaa92a81e7d934eef7fd3c76b401915&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_6dbc55718bd746a0ddadf212a31ebb0c.setContent(html_bcaa92a81e7d934eef7fd3c76b401915);
#
#
#
#         circle_6ef228ce9c1e5c311d3aeff73d761f20.bindPopup(popup_6dbc55718bd746a0ddadf212a31ebb0c)
#         ;
#
#
#
#
#             var circle_8b2aa22d9cabaf97515e9040f9e3c27e = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d4b57b6ff951cbd3c5296be773de1280);
#
#
#         var popup_b395461f45c738995184e33b0442a3c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6260423ac36c3d59757ff9c87091d765 = $(`&lt;div id=&quot;html_6260423ac36c3d59757ff9c87091d765&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_b395461f45c738995184e33b0442a3c6.setContent(html_6260423ac36c3d59757ff9c87091d765);
#
#
#
#         circle_8b2aa22d9cabaf97515e9040f9e3c27e.bindPopup(popup_b395461f45c738995184e33b0442a3c6)
#         ;
#
#
#
#
#             var circle_46cfa42640eeb4f385104f6666f53169 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d4b57b6ff951cbd3c5296be773de1280);
#
#
#         var popup_03009ee16843c1c08c71308098b67044 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a8b8c8215f7768e4557eeca38eb8189 = $(`&lt;div id=&quot;html_4a8b8c8215f7768e4557eeca38eb8189&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_03009ee16843c1c08c71308098b67044.setContent(html_4a8b8c8215f7768e4557eeca38eb8189);
#
#
#
#         circle_46cfa42640eeb4f385104f6666f53169.bindPopup(popup_03009ee16843c1c08c71308098b67044)
#         ;
#
#
#
#
#             var circle_fa7f88beb6fd9c07756b8eaf87dc0d98 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru

# %%
# Building choropleth map

df_world_countries = pd.read_json('C:\\Users\\Edwin\\Downloads\\world-countries.json')
df_unemployment = pd.read_csv('C:\\Users\\Edwin\\Downloads\\unemployment.csv', skiprows=4, delimiter=',')

df_unemployment
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tl/q1c606q156xbmnyd03bvkf7r0000gn/T/ipykernel_34927/3823007937.py in <module>
#       1 # Building choropleth map
#       2
# ----> 3 df_world_countries = pd.read_json('C:\\Users\\Edwin\\Downloads\\world-countries.json')
#       4 df_unemployment = pd.read_csv('C:\\Users\\Edwin\\Downloads\\unemployment.csv', skiprows=4, delimiter=',')
#       5
#
# ~/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     612
#     613     with json_reader:
# --> 614         return json_reader.read()
#     615
#     616
#
# ~/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     746                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     747         else:
# --> 748             obj = self._get_object_parser(self.data)
#     749         self.close()
#     750         return obj
#
# ~/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#     772         if typ == "series" or obj is None:
#
# ~/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     883
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#     887         if self.obj is None:
#
# ~/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1138         if orient == "columns":
#    1139             self.obj = DataFrame(
# -> 1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#    1142         elif orient == "split":
#
# ValueError: Expected object or value

# %%
df_unemployment_2018 = df_unemployment[['Country Name', 'Country Code', '2018']]
df_unemployment_2018.head(10)

# %%
# Remove nulls

df_unemployment_2018_clean = df_unemployment_2018.dropna()
df_unemployment_2018_clean.head(10)

# %%
df_unemployment_2018_clean.shape

# %%
# prepare data for our map
legendTitle = 'Unemployment rate per country 2018 (%)'

# Data to plot country code and value
data_unemployment = df_unemployment_2018_clean[['Country Code', '2018']]

data_unemployment.head()

# %%
# Setup the map
map_unemployment = folium.Map(location=[8.7832, 34.5085], zoom_start=3)

map_unemployment.choropleth(geo_data='C:\\Users\\Edwin\\Downloads\\world-countries.json',
                           data=data_unemployment,
                           columns=['Country Code', '2018'],
                           key_on='feature.id',
                           fill_color='YlOrRd',
                           fill_opacity=0.7,
                           line_opacity=0.2,
                           legend_name=legendTitle)

map_unemployment

# %%
# Measuring Boundries

df_damLevels = pd.read_csv('https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/master/DamLevels.txt', delimiter=',')

df_damLevels.head()

# %%
df_location = pd.read_csv('https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/master/damLocations.txt', delimiter=',')

df_location.head()

# %%
# Join the two dataframes on the dam field
df_damData = pd.merge(df_damLevels, df_location, on='Dam', how='left')

df_damData.head()

# %%
# Prepare data to plot
df_dams_locations = df_damData[['Latitude', 'Longitude']]
dams_location_list = df_dams_locations.values.tolist()
dams_location_list_size = len(dams_location_list)
dams_location_list_size

# %%
map_dams = folium.Map(location=[-33.925, 18.625], zoom_start=10)
for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_dams)
    
map_dams

# %%
map_url = folium.Map(location=[-34.078100, 19.289200],
                    tiles='http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                    zoom_start=12,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community')

for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_url)

map_url

# %%
from folium.plugins import MeasureControl

map_url.add_child(MeasureControl())

map_url

# %%
# Add Layer Control
map_layers = map_points

add = '/MapServer/tile/{z}/{y}/{x}'
ESRI = dict(World_Ocean_Base='http://services.arcgisonline.com/arcgis/rest/services/Ocean/World_Ocean_Base',
            World_Navigation_Charts='http://services.arcgisonline.com/ArcGIS/rest/services/Specialty/World_Navigation_Charts',
            NatGeo_World_Map='http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer',
            World_Imagery='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer',
            World_Physical_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Physical_Map/MapServer',
            World_Shaded_Relief='http://services.arcgisonline.com/arcgis/rest/services/World_Shaded_Relief/MapServer',
            World_Street_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Street_Map/MapServer',
            World_Terrain_Base='http://services.arcgisonline.com/arcgis/rest/services/World_Terrain_Base/MapServer',
            World_Topo_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Topo_Map/MapServer')


for tile_name, tile_url in ESRI.items():
    tile_url += add
    folium.TileLayer(tile_url,
                    name=tile_name,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community').add_to(map_points)
    

folium.LayerControl().add_to(map_layers)

map_layers

# %%
# Creating Heatmap

from folium.plugins import HeatMap

# Create our point map object
map_heat = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius='15',
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_heat)
    
# convert to array format for our heatmap
suburbsArray = df_suburbs[['Latitude', 'Longitude']].values

# plot heatmap
map_heat.add_child(HeatMap(suburbsArray))

map_heat

# %%
# !pip install selenium

# %%
import os
import time
from selenium import webdriver

# %%
delay = 5

heat = 'map_heat.html'
unemployment = 'map_unemployment.html'

def export_maps(map_file, map_image, map_obj):
    browser = webdriver.Chrome('C:\\Users\\Edwin\\Downloads\\chromedriver_win32\\chromedriver.exe')
    tmpUrl = 'file://{path}/{mapfile}'.format(path=os.getcwd(), mapfile=map_file)
    map_obj.save(map_file)
    browser.get(tmpUrl)
    time.sleep(delay)
    browser.save_screenshot(map_image)
    browser.quit()
    
export_maps(heat, 'map_heat.png', map_heat)

# %%
export_maps(unemployment, 'map_unemployment.png', map_unemployment)
