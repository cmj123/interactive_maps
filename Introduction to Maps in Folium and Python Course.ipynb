# %%
import folium
import pandas as pd

# %%
df_suburbs = pd.read_excel('waterwatch_clean2.xlsx', sheet_name='Sheet1')

df_suburbs.head()
# Out:
#    Unnamed: 0           Suburb  \
# 0           0          ATHLONE
# 1           1           AURORA
# 2           2       BANTRY BAY
# 3           3  BELLVILLE SOUTH
# 4           4        BERGVLIET
#
#    Number of single-residential properties_number  Oct 2017\nkl/month  \
# 0                                            2272                  11
# 1                                             426                  10
# 2                                             248                  13
# 3                                            2041                  11
# 4                                            1488                   8
#
#      Month  Year   Latitude  Longitude
# 0  October  2017 -33.967220  18.502140
# 1  October  2017 -32.705958  18.485135
# 2  October  2017 -33.927953  18.382592
# 3  October  2017 -33.920011  18.642819
# 4  October  2017 -34.047464  18.452499

# %%
df_suburbs.columns
# Out:
# Index(['Unnamed: 0', 'Suburb',
#        'Number of single-residential properties_number', 'Oct 2017\nkl/month',
#        'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_suburbs.shape
# Out:
# (121, 8)

# %%
df_suburbs.describe()
# Out:
#        Unnamed: 0  Number of single-residential properties_number  \
# count  121.000000                                      121.000000
# mean    60.000000                                     1849.983471
# std     35.073732                                     2506.756526
# min      0.000000                                        0.000000
# 25%     30.000000                                      364.000000
# 50%     60.000000                                     1009.000000
# 75%     90.000000                                     2411.000000
# max    120.000000                                    20719.000000
#
#        Oct 2017\nkl/month    Year    Latitude   Longitude
# count          121.000000   121.0  121.000000  121.000000
# mean             8.413223  2017.0  -33.944923   18.668673
# std              3.275336     0.0    0.217793    0.568946
# min              0.000000  2017.0  -34.589721   18.329108
# 25%              8.000000  2017.0  -34.037828   18.457490
# 50%              9.000000  2017.0  -33.950865   18.505041
# 75%             10.000000  2017.0  -33.908311   18.638249
# max             13.000000  2017.0  -32.705958   22.192635

# %%
map_osm = folium.Map(location=[-33.925, 18.625], zoom_start=10)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894a2f355980c805051e6eeca53c1e94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894a2f355980c805051e6eeca53c1e94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_894a2f355980c805051e6eeca53c1e94 = L.map(
#                 &quot;map_894a2f355980c805051e6eeca53c1e94&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8f50d07779daed206165b540ea50090 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_dark = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17a4b9b52a73d6317dca7278c7dd303c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17a4b9b52a73d6317dca7278c7dd303c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17a4b9b52a73d6317dca7278c7dd303c = L.map(
#                 &quot;map_17a4b9b52a73d6317dca7278c7dd303c&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6708b48b30c478b50614fe1bef954b8 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_17a4b9b52a73d6317dca7278c7dd303c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_suburbs_locations = df_suburbs[['Latitude', 'Longitude']]
#df_suburbs_locations
suburbs_location_list = df_suburbs_locations.values.tolist()
suburbs_location_list_size = len(suburbs_location_list)
suburbs_location_list_size
# Out:
# 121

# %%
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point]).add_to(map_osm)
    folium.Marker(suburbs_location_list[point]).add_to(map_dark)
    
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894a2f355980c805051e6eeca53c1e94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894a2f355980c805051e6eeca53c1e94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_894a2f355980c805051e6eeca53c1e94 = L.map(
#                 &quot;map_894a2f355980c805051e6eeca53c1e94&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8f50d07779daed206165b540ea50090 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_ec8f1b79202d49d3a760e5ac93f7de6a = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_48af79ba7d9c2c4b35db3593a5129891 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_b32975060dbeaa368e6e0a2017c152a1 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_1be73acb1c040f6f2f4e60f1b1a7cca9 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_471b32962797b0e4bda682c99074c987 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_34b808653221046773450c9ae709b8f5 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_e00b937698c4dddd0a1de7e307b9c73a = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_dfdbc251c993ebc6d92c2996e4c71586 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_7a73ee9e8dc2cf58f1a3d5a86ad4f1b0 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_b3fc2d13e7fa9287e818ad53d83156d3 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_a05cd55b50085366e4de04828d5d25d5 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker_32c21421452c637c88dbfa0f11c52c0b = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_894a2f355980c805051e6eeca53c1e94);
#
#
#             var marker
= L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_17a4b9b52a73d6317dca7278c7dd303c);
#
#
#             var marker_294d394aa9b2eccc7c0e5d87a6c405ba = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_17a4b9b52a73d6317dca7278c7dd303c);
#
#
#             var marker_2c640fc797e7d0ec30d2c5290542aef2 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_17a4b9b52a73d6317dca7278c7dd303c);
#
#
#             var marker_a854f8c142cac783494cc78e9e0b5356 =

# %%
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3fd88181a3c171e87be585cbcea241c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3fd88181a3c171e87be585cbcea241c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3fd88181a3c171e87be585cbcea241c = L.map(
#                 &quot;map_d3fd88181a3c171e87be585cbcea241c&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1753a95c0c6a7219e9c0d2572fb37a2 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d3fd88181a3c171e87be585cbcea241c);
#
#
#             var circle_bd323a71de3fa194cdcb8aaed5d31dd4 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d3fd88181a3c171e87be585cbcea241c);
#
#
#         var popup_683a62901ead5264b70185235495f19b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad5b4ab05385919f725a7945353c9dc8 = $(`&lt;div id=&quot;html_ad5b4ab05385919f725a7945353c9dc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_683a62901ead5264b70185235495f19b.setContent(html_ad5b4ab05385919f725a7945353c9dc8);
#
#
#
#         circle_bd323a71de3fa194cdcb8aaed5d31dd4.bindPopup(popup_683a62901ead5264b70185235495f19b)
#         ;
#
#
#
#
#             var circle_6e77baed2b33bac5302664ce7e5b8617 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d3fd88181a3c171e87be585cbcea241c);
#
#
#         var popup_bdf389beb10b8fe2ee32a267cc8fbe8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_699f5c7784846bd69ef65e3376bc0b84 = $(`&lt;div id=&quot;html_699f5c7784846bd69ef65e3376bc0b84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_bdf389beb10b8fe2ee32a267cc8fbe8b.setContent(html_699f5c7784846bd69ef65e3376bc0b84);
#
#
#
#         circle_6e77baed2b33bac5302664ce7e5b8617.bindPopup(popup_bdf389beb10b8fe2ee32a267cc8fbe8b)
#         ;
#
#
#
#
#             var circle_bfb050dbc6a2200eeb3c79e0391f977c = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d3fd88181a3c171e87be585cbcea241c);
#
#
#         var popup_28e0c042c562e8b67c84286dc3ecc08a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fee521c0b1da5323e3b9151346276dec = $(`&lt;div id=&quot;html_fee521c0b1da5323e3b9151346276dec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_28e0c042c562e8b67c84286dc3ecc08a.setContent(html_fee521c0b1da5323e3b9151346276dec);
#
#
#
#         circle_bfb050dbc6a2200eeb3c79e0391f977c.bindPopup(popup_28e0c042c562e8b67c84286dc3ecc08a)
#         ;
#
#
#
#
#             var circle_b95acafc0a8bf8b2ab4076a7affd8463 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &

# %%
# Adding Classification
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    # Classify by usage
    if df_suburbs['Oct 2017\nkl/month'][point] <= 8 and df_suburbs['Oct 2017\nkl/month'][point] > 0:
        usage_color = 'green'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 8 and df_suburbs['Oct 2017\nkl/month'][point] <= 10:
        usage_color = '#17cbef'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 10:
        usage_color = 'red'
    else: # Outliers
        usage_color = 'orange'
        
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color=usage_color,
        fill=True,
        opacity=0.8,
        fill_color=usage_color,
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_046281e8cdc8702e38a6873cc50cf892 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_046281e8cdc8702e38a6873cc50cf892&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_046281e8cdc8702e38a6873cc50cf892 = L.map(
#                 &quot;map_046281e8cdc8702e38a6873cc50cf892&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ee40acd9ac509e91bf7577e1a5e0546 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_046281e8cdc8702e38a6873cc50cf892);
#
#
#             var circle_cd740451ceaeec38a9e69cb6cba07f64 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_046281e8cdc8702e38a6873cc50cf892);
#
#
#         var popup_b66b981097669a70945dcb0a2db1881e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2cbf4888d4b30310e0001e428adcf540 = $(`&lt;div id=&quot;html_2cbf4888d4b30310e0001e428adcf540&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_b66b981097669a70945dcb0a2db1881e.setContent(html_2cbf4888d4b30310e0001e428adcf540);
#
#
#
#         circle_cd740451ceaeec38a9e69cb6cba07f64.bindPopup(popup_b66b981097669a70945dcb0a2db1881e)
#         ;
#
#
#
#
#             var circle_1b7ebb0d17e9280150047e5ef874f865 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_046281e8cdc8702e38a6873cc50cf892);
#
#
#         var popup_4593013c295cb177656b5b9271602f01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eec812fa8dd04516154b2895964f04fe = $(`&lt;div id=&quot;html_eec812fa8dd04516154b2895964f04fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_4593013c295cb177656b5b9271602f01.setContent(html_eec812fa8dd04516154b2895964f04fe);
#
#
#
#         circle_1b7ebb0d17e9280150047e5ef874f865.bindPopup(popup_4593013c295cb177656b5b9271602f01)
#         ;
#
#
#
#
#             var circle_d089bf5aaedea64b0ddff4b25886a84a = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_046281e8cdc8702e38a6873cc50cf892);
#
#
#         var popup_076e85e44843fd0a5af955e5fd01ef36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d21752d400d341144a648daba4379f5c = $(`&lt;div id=&quot;html_d21752d400d341144a648daba4379f5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_076e85e44843fd0a5af955e5fd01ef36.setContent(html_d21752d400d341144a648daba4379f5c);
#
#
#
#         circle_d089bf5aaedea64b0ddff4b25886a84a.bindPopup(popup_076e85e44843fd0a5af955e5fd01ef36)
#         ;
#
#
#
#
#             var circle_5ec66d12af143880be0b30a7796e2073 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru

# %%
# Building choropleth map

df_world_countries = pd.read_json('world-countries.json')
df_unemployment = pd.read_csv('unemployment.csv', skiprows=4, delimiter=',')

df_unemployment
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 1    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 2    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 3    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 4    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# ..                                                 ...             ...   ...
# 259  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 260  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 261  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 262  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 263  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010   2011    2012    2013  \
# 0     NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# 1     NaN   NaN   NaN   NaN   NaN  ...   7.821000   8.23   7.936   8.452
# 2     NaN   NaN   NaN   NaN   NaN  ...   9.863000   7.36   7.347   7.331
# 3     NaN   NaN   NaN   NaN   NaN  ...  14.200000  13.98  13.440  15.640
# 4     NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# ..    ...   ...   ...   ...   ...  ...        ...    ...     ...     ...
# 259   NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# 260   NaN   NaN   NaN   NaN   NaN  ...  17.820000  16.99  15.277  14.163
# 261   NaN   NaN   NaN   NaN   NaN  ...  24.690001  24.65  24.730  24.570
# 262   NaN   NaN   NaN   NaN   NaN  ...  13.190000   9.99   7.850   7.816
# 263   NaN   NaN   NaN   NaN   NaN  ...   5.272000   5.37   5.328   5.205
#
#        2014    2015       2016    2017       2018  Unnamed: 63
# 0       NaN     NaN        NaN     NaN        NaN          NaN
# 1     8.706   8.864   8.841000   8.837   8.808000          NaN
# 2     7.306   7.281   7.724000   8.167   8.543000          NaN
# 3    17.490  17.080  15.220000  13.867  15.132000          NaN
# 4       NaN     NaN        NaN     NaN        NaN          NaN
# ..      ...     ...        ...     ...        ...          ...
# 259     NaN     NaN        NaN     NaN        NaN          NaN
# 260  13.470  13.807  13.729000  14.036  14.167000          NaN
# 261  24.900  25.160  26.549999  27.330  27.372999          NaN
# 262   7.783   7.750   7.777000   7.792   7.797000          NaN
# 263   5.135   5.086   5.046000   5.011   4.985000          NaN
#
# [264 rows x 64 columns]

# %%
df_unemployment_2018 = df_unemployment[['Country Name', 'Country Code', '2018']]
df_unemployment_2018.head(10)
# Out:
#            Country Name Country Code       2018
# 0                 Aruba          ABW        NaN
# 1           Afghanistan          AFG   8.808000
# 2                Angola          AGO   8.543000
# 3               Albania          ALB  15.132000
# 4               Andorra          AND        NaN
# 5            Arab World          ARB   9.808109
# 6  United Arab Emirates          ARE   1.710000
# 7             Argentina          ARG   8.162000
# 8               Armenia          ARM  18.275999
# 9        American Samoa          ASM        NaN

# %%
# Remove nulls

df_unemployment_2018_clean = df_unemployment_2018.dropna()
df_unemployment_2018_clean.head(10)
# Out:
#             Country Name Country Code       2018
# 1            Afghanistan          AFG   8.808000
# 2                 Angola          AGO   8.543000
# 3                Albania          ALB  15.132000
# 5             Arab World          ARB   9.808109
# 6   United Arab Emirates          ARE   1.710000
# 7              Argentina          ARG   8.162000
# 8                Armenia          ARM  18.275999
# 11             Australia          AUS   5.474000
# 12               Austria          AUT   5.387000
# 13            Azerbaijan          AZE   5.037000

# %%
df_unemployment_2018_clean.shape
# Out:
# (233, 3)

# %%
# prepare data for our map
legendTitle = 'Unemployment rate per country 2018 (%)'

# Data to plot country code and value
data_unemployment = df_unemployment_2018_clean[['Country Code', '2018']]

data_unemployment.head()
# Out:
#   Country Code       2018
# 1          AFG   8.808000
# 2          AGO   8.543000
# 3          ALB  15.132000
# 5          ARB   9.808109
# 6          ARE   1.710000

# %%
# Setup the map
map_unemployment = folium.Map(location=[8.7832, 34.5085], zoom_start=3)

map_unemployment.choropleth(geo_data='world-countries.json',
                           data=data_unemployment,
                           columns=['Country Code', '2018'],
                           key_on='feature.id',
                           fill_color='YlOrRd',
                           fill_opacity=0.7,
                           line_opacity=0.2,
                           legend_name=legendTitle)

map_unemployment
# Out:
# /Users/esuabomdijemeni/Desktop/github/interactive_maps/venv/lib/python3.7/site-packages/folium/folium.py:411: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b17f09a5fd8eb1efa6bb63ccec0b4687 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b17f09a5fd8eb1efa6bb63ccec0b4687&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b17f09a5fd8eb1efa6bb63ccec0b4687 = L.map(
#                 &quot;map_b17f09a5fd8eb1efa6bb63ccec0b4687&quot;,
#                 {
#                     center: [8.7832, 34.5085],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cbcc5686949e34e9a205a176f986928 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b17f09a5fd8eb1efa6bb63ccec0b4687);
#
#
#             var choropleth_2de44484442d9aad57b5b59f62d3c655 = L.featureGroup(
#                 {}
#             ).addTo(map_b17f09a5fd8eb1efa6bb63ccec0b4687);
#
#
#         function geo_json_aa01710a91c310de69405f97b592e2f1_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Afghanistan&quot;: case &quot;Angola&quot;: case &quot;Argentina&quot;: case &quot;Australia&quot;: case &quot;Austria&quot;: case &quot;Azerbaijan&quot;: case &quot;Belgium&quot;: case &quot;Burkina Faso&quot;: case &quot;Bulgaria&quot;: case &quot;Belize&quot;: case &quot;Brunei&quot;: case &quot;Central African Republic&quot;: case &quot;Canada&quot;: case &quot;Chile&quot;: case &quot;Colombia&quot;: case &quot;Costa Rica&quot;: case &quot;Djibouti&quot;: case &quot;Denmark&quot;: case &quot;Dominican Republic&quot;: case &quot;Eritrea&quot;: case &quot;Estonia&quot;: case &quot;Ethiopia&quot;: case &quot;Finland&quot;: case &quot;Fiji&quot;: case &quot;France&quot;: case &quot;Gambia&quot;: case &quot;Guinea Bissau&quot;: case &quot;Equatorial Guinea&quot;: case &quot;Croatia&quot;: case &quot;Ireland&quot;: case &quot;Iraq&quot;: case &quot;Kazakhstan&quot;: case &quot;Kyrgyzstan&quot;: case &quot;Lebanon&quot;: case &quot;Lithuania&quot;: case &quot;Luxembourg&quot;: case &quot;Latvia&quot;: case &quot;Morocco&quot;: case &quot;Mali&quot;: case &quot;Mongolia&quot;: case &quot;Malawi&quot;: case &quot;Nigeria&quot;: case &quot;New Zealand&quot;: case &quot;Portugal&quot;: case &quot;Russia&quot;: case &quot;Saudi Arabia&quot;: case &quot;Somalia&quot;: case &quot;Suriname&quot;: case &quot;Slovakia&quot;: case &quot;Slovenia&quot;: case &quot;Sweden&quot;: case &quot;Chad&quot;: case &quot;Trinidad and Tobago&quot;: case &quot;Ukraine&quot;: case &quot;Uruguay&quot;: case &quot;Uzbekistan&quot;: case &quot;Venezuela&quot;: case &quot;Vanuatu&quot;: case &quot;Zambia&quot;: case &quot;Zimbabwe&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Albania&quot;: case &quot;Armenia&quot;: case &quot;Botswana&quot;: case &quot;Spain&quot;: case &quot;Jordan&quot;: case &quot;Libya&quot;: case &quot;Montenegro&quot;: case &quot;New Caledonia&quot;: case &quot;Syria&quot;: case &quot;Tunisia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Antarctica&quot;: case &quot;French Southern and Antarctic Lands&quot;: case &quot;Northern Cyprus&quot;: case &quot;Falkland Islands&quot;: case &quot;Greenland&quot;: case &quot;Kosovo&quot;: case &quot;Western Sahara&quot;: case &quot;South Sudan&quot;: case &quot;Somaliland&quot;: case &quot;Taiwan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;The Bahamas&quot;: case &quot;Brazil&quot;: case &quot;Republic of the Congo&quot;: case &quot;Cyprus&quot;: case &quot;Algeria&quot;: case &quot;Egypt&quot;: case &quot;Georgia&quot;: case &quot;Guyana&quot;: case &quot;Haiti&quot;: case &quot;Iran&quot;: case &quot;Italy&quot;: case &quot;Jamaica&quot;: case &quot;Kenya&quot;: case &quot;Mauritania&quot;: case &quot;Puerto Rico&quot;: case &quot;Sudan&quot;: case &quot;Republic of Serbia&quot;: case &quot;Tajikistan&quot;: case &quot;Turkey&quot;: case &quot;Yemen&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Bosnia and Herzegovina&quot;: case &quot;Lesotho&quot;: case &quot;Mozambique&quot;: case &quot;Swaziland&quot;: case &quot;West Bank&quot;: case &quot;South Africa&quot;:

# %%
# Measuring Boundries

df_damLevels = pd.read_csv('https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/master/DamLevels.txt', delimiter=',')

df_damLevels.head()
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras Dam-Lower        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras Dam-Upper        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
#
#    ThisWeek  LastWeek  LastYear
# 0      73.7      75.2      49.9
# 1      50.2      51.7      35.6
# 2      70.0      69.8      92.4
# 3      40.9      41.9      10.6
# 4      65.6      67.5      15.5

# %%
df_location = pd.read_csv('https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/master/damLocations.txt', delimiter=',')

df_location.head()
# Out:
#                    Dam   Latitude  Longitude
# 0       Berg River Dam -33.925000  19.060833
# 1  Steenbras Dam-Upper -34.166300  18.910000
# 2  Steenbras Dam-Lower -34.179722  18.876389
# 3  Theewaterskloof Dam -34.078100  19.289200
# 4         Voelvlei Dam -33.337500  19.033600

# %%
# Join the two dataframes on the dam field
df_damData = pd.merge(df_damLevels, df_location, on='Dam', how='left')

df_damData.head()
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras Dam-Lower        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras Dam-Upper        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
#
#    ThisWeek  LastWeek  LastYear   Latitude  Longitude
# 0      73.7      75.2      49.9 -33.925000  19.060833
# 1      50.2      51.7      35.6 -34.179722  18.876389
# 2      70.0      69.8      92.4 -34.166300  18.910000
# 3      40.9      41.9      10.6 -34.078100  19.289200
# 4      65.6      67.5      15.5 -33.337500  19.033600

# %%
# Prepare data to plot
df_dams_locations = df_damData[['Latitude', 'Longitude']]
dams_location_list = df_dams_locations.values.tolist()
dams_location_list_size = len(dams_location_list)
dams_location_list_size
# Out:
# 6

# %%
map_dams = folium.Map(location=[-33.925, 18.625], zoom_start=10)
for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_dams)
    
map_dams
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9443e9d1fd94e4c1c4515d20d59e56f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9443e9d1fd94e4c1c4515d20d59e56f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9443e9d1fd94e4c1c4515d20d59e56f = L.map(
#                 &quot;map_c9443e9d1fd94e4c1c4515d20d59e56f&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4dd3b1d2389a9e9822e078bb5dd86e01 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c9443e9d1fd94e4c1c4515d20d59e56f);
#
#
#             var marker_7755f241c2543f36cb89fc3ef8497539 = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_c9443e9d1fd94e4c1c4515d20d59e56f);
#
#
#         var popup_46a4b7e75a88cb8a2bc6d4d4d4f07877 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c8f27dbd3ea4ca0e94db034693d3dc2 = $(`&lt;div id=&quot;html_4c8f27dbd3ea4ca0e94db034693d3dc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_46a4b7e75a88cb8a2bc6d4d4d4f07877.setContent(html_4c8f27dbd3ea4ca0e94db034693d3dc2);
#
#
#
#         marker_7755f241c2543f36cb89fc3ef8497539.bindPopup(popup_46a4b7e75a88cb8a2bc6d4d4d4f07877)
#         ;
#
#
#
#
#             var marker_947f78ab324c2baa477250009327c026 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_c9443e9d1fd94e4c1c4515d20d59e56f);
#
#
#         var popup_9df89b923598d433b388d9587e9f3301 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d4ef9d2be8e57bcba06d6cf2773a215 = $(`&lt;div id=&quot;html_1d4ef9d2be8e57bcba06d6cf2773a215&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_9df89b923598d433b388d9587e9f3301.setContent(html_1d4ef9d2be8e57bcba06d6cf2773a215);
#
#
#
#         marker_947f78ab324c2baa477250009327c026.bindPopup(popup_9df89b923598d433b388d9587e9f3301)
#         ;
#
#
#
#
#             var marker_f2bf8e2d21945dd3050591b76198aad4 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_c9443e9d1fd94e4c1c4515d20d59e56f);
#
#
#         var popup_93e5a2d71ffddf2943b7bc8c11159ff4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fdba620b26e14a97213f115394ee3fed = $(`&lt;div id=&quot;html_fdba620b26e14a97213f115394ee3fed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_93e5a2d71ffddf2943b7bc8c11159ff4.setContent(html_fdba620b26e14a97213f115394ee3fed);
#
#
#
#         marker_f2bf8e2d21945dd3050591b76198aad4.bindPopup(popup_93e5a2d71ffddf2943b7bc8c11159ff4)
#         ;
#
#
#
#
#             var marker_8863326d0edc817fe5fbf4ed2b797b21 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_c9443e9d1fd94e4c1c4515d20d59e56f);
#
#
#         var popup_e8b3ff71cd3ba831114ca35e6bfa5fda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_883af68ed9c28ed58e5bcc01a49f9638 = $(`&lt;div id=&quot;html_883af68ed9c28ed58e5bcc01a49f9638&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_e8b3ff71cd3ba831114ca35e6bfa5fda.setContent(html_883af68ed9c28ed58e5bcc01a49f9638);
#
#
#
#         marker_8863326d0edc817fe5fbf4ed2b797b21.bindPopup(popup_e8b3ff71cd3ba831114ca35e6bfa5fda)
#         ;
#
#
#
#
#             var marker_91b67bf86c0cc18c86905ce7bdbe841d = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_c9443e9d1fd94e4c1c4515d20d59e56f);
#
#
#         var popup_adcfed0b7b4160327831260c199369b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d88f53b5e8be5f1a3b78198205637f40 = $(`&lt;div id=&quot;html_d88f53b5e8be5f1a3b78198205637f40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_adcfed0b7b4160327831260c199369b8.setContent(html_d88f53b5e8be5f1a3b78198205637f40);
#
#
#
#         marker_91b67bf86c0cc18c86905ce7bdbe841d.bindPopup(popup_adcfed0b7b4160327831260c199369b8)
#         ;
#
#
#
#
#             var marker_a533cbde2e4ef85c8b1282b319c4bb98 = L.marker(
#                 [-33.8336, 19.0889],
#                 {}
#             ).addTo(map_c9443e9d1fd94e4c1c4515d20d59e56f);
#
#
#         var popup_62e8c0839a7ebe1b25dc728f50dfa9

# %%
map_url = folium.Map(location=[-34.078100, 19.289200],
                    tiles='http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                    zoom_start=12,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community')

for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_url)

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb0337a2d14ba4985205367cd60f3f74 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb0337a2d14ba4985205367cd60f3f74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb0337a2d14ba4985205367cd60f3f74 = L.map(
#                 &quot;map_bb0337a2d14ba4985205367cd60f3f74&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_829945c74bfb80847040fb822ba0d1e7 = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#             var marker_3f155962a060f07401c0eb874c16356b = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_38a34a905cd36b0d403922014beab15a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c933861103f817d3b92d24f72e26b93 = $(`&lt;div id=&quot;html_9c933861103f817d3b92d24f72e26b93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_38a34a905cd36b0d403922014beab15a.setContent(html_9c933861103f817d3b92d24f72e26b93);
#
#
#
#         marker_3f155962a060f07401c0eb874c16356b.bindPopup(popup_38a34a905cd36b0d403922014beab15a)
#         ;
#
#
#
#
#             var marker_17b87311f4dc05d80576039a61ab1ff2 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_ea0070ec471100b01cf5a6125f787d18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3541b520edf58dc3e9815d1b09c4d2de = $(`&lt;div id=&quot;html_3541b520edf58dc3e9815d1b09c4d2de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_ea0070ec471100b01cf5a6125f787d18.setContent(html_3541b520edf58dc3e9815d1b09c4d2de);
#
#
#
#         marker_17b87311f4dc05d80576039a61ab1ff2.bindPopup(popup_ea0070ec471100b01cf5a6125f787d18)
#         ;
#
#
#
#
#             var marker_0461746d6c6e15e3cfa20b3a0b1e8354 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_fb4b50c81734f0fab30bb8bb4b742be2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80f28c64e88e8f47b52a948e5c492d3c = $(`&lt;div id=&quot;html_80f28c64e88e8f47b52a948e5c492d3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_fb4b50c81734f0fab30bb8bb4b742be2.setContent(html_80f28c64e88e8f47b52a948e5c492d3c);
#
#
#
#         marker_0461746d6c6e15e3cfa20b3a0b1e8354.bindPopup(popup_fb4b50c81734f0fab30bb8bb4b742be2)
#         ;
#
#
#
#
#             var marker_620a8e6cbf7db233e37d296889743b71 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_39de35a830630c5a1d91527a1a9222ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44995ce3583a79daf889e0ece52f08fd = $(`&lt;div id=&quot;html_44995ce3583a79daf889e0ece52f08fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_39de35a830630c5a1d91527a1a9222ef.setContent(html_44995ce3583a79daf889e0ece52f08fd);
#
#
#
#         marker_620a8e6cbf7db233e37d296889743b71.bindPopup(popup_39de35a830630c5a1d91527a1a9222ef)
#         ;
#
#
#
#
#             var marker_eb824051c13a985d7ea50e95526552c8 = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_6e88597a74f37ac0b7cfbccd5792900e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d74d81536b87a06eb7ffd350a782181 = $(`&lt;div id=&quot;html_1d74d81536b87a06eb7ffd350a782181&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_6e88597a74f37ac0b7cfbccd5792900e.setContent(html_1d74d81536b87a06eb7ffd350a782181);
#
#
#
#         marker_eb824051c13a985d7ea50e95526552c8.bindPopup(popup_6e88597a74f37ac0b7cfbccd5792900e)
#         ;
#
#
#
#
#             var marker_c68df0138fad54d323f221af5c3d2cef = L.marker(
#                 [-33.8336, 19.0889],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_3f5927fa1a07f917efccd28fd7caada7 =

# %%
from folium.plugins import MeasureControl

map_url.add_child(MeasureControl())

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb0337a2d14ba4985205367cd60f3f74 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb0337a2d14ba4985205367cd60f3f74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb0337a2d14ba4985205367cd60f3f74 = L.map(
#                 &quot;map_bb0337a2d14ba4985205367cd60f3f74&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_829945c74bfb80847040fb822ba0d1e7 = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#             var marker_3f155962a060f07401c0eb874c16356b = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_38a34a905cd36b0d403922014beab15a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c933861103f817d3b92d24f72e26b93 = $(`&lt;div id=&quot;html_9c933861103f817d3b92d24f72e26b93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_38a34a905cd36b0d403922014beab15a.setContent(html_9c933861103f817d3b92d24f72e26b93);
#
#
#
#         marker_3f155962a060f07401c0eb874c16356b.bindPopup(popup_38a34a905cd36b0d403922014beab15a)
#         ;
#
#
#
#
#             var marker_17b87311f4dc05d80576039a61ab1ff2 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_ea0070ec471100b01cf5a6125f787d18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3541b520edf58dc3e9815d1b09c4d2de = $(`&lt;div id=&quot;html_3541b520edf58dc3e9815d1b09c4d2de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_ea0070ec471100b01cf5a6125f787d18.setContent(html_3541b520edf58dc3e9815d1b09c4d2de);
#
#
#
#         marker_17b87311f4dc05d80576039a61ab1ff2.bindPopup(popup_ea0070ec471100b01cf5a6125f787d18)
#         ;
#
#
#
#
#             var marker_0461746d6c6e15e3cfa20b3a0b1e8354 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_fb4b50c81734f0fab30bb8bb4b742be2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80f28c64e88e8f47b52a948e5c492d3c = $(`&lt;div id=&quot;html_80f28c64e88e8f47b52a948e5c492d3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_fb4b50c81734f0fab30bb8bb4b742be2.setContent(html_80f28c64e88e8f47b52a948e5c492d3c);
#
#
#
#         marker_0461746d6c6e15e3cfa20b3a0b1e8354.bindPopup(popup_fb4b50c81734f0fab30bb8bb4b742be2)
#         ;
#
#
#
#
#             var marker_620a8e6cbf7db233e37d296889743b71 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_39de35a830630c5a1d91527a1a9222ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44995ce3583a79daf889e0ece52f08fd = $(`&lt;div id=&quot;html_44995ce3583a79daf889e0ece52f08fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_39de35a830630c5a1d91527a1a9222ef.setContent(html_44995ce3583a79daf889e0ece52f08fd);
#
#
#
#         marker_620a8e6cbf7db233e37d296889743b71.bindPopup(popup_39de35a830630c5a1d91527a1a9222ef)
#         ;
#
#
#
#
#             var marker_eb824051c13a985d7ea50e95526552c8 = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_bb0337a2d14ba4985205367cd60f3f74);
#
#
#         var popup_6e88597a74f37ac0b7cfbccd5792900e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d74d81536b87a06eb7ffd350a782181 = $(`&lt;div id=&quot;html_1d74d81536b87a06eb7ffd350a782181&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_6e88597a74f37ac0b7cfbccd5792900e.setContent(html_1d74d81536b87a06eb7ffd350a782181);
#
#
#
#         marker_eb824051c13a985d7ea50e95526552c8.bindPopup(popup_6e88597a74f37ac0b7cfbccd5792900

# %%
# Add Layer Control
map_layers = map_points

add = '/MapServer/tile/{z}/{y}/{x}'
ESRI = dict(World_Ocean_Base='http://services.arcgisonline.com/arcgis/rest/services/Ocean/World_Ocean_Base',
            World_Navigation_Charts='http://services.arcgisonline.com/ArcGIS/rest/services/Specialty/World_Navigation_Charts',
            NatGeo_World_Map='http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer',
            World_Imagery='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer',
            World_Physical_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Physical_Map/MapServer',
            World_Shaded_Relief='http://services.arcgisonline.com/arcgis/rest/services/World_Shaded_Relief/MapServer',
            World_Street_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Street_Map/MapServer',
            World_Terrain_Base='http://services.arcgisonline.com/arcgis/rest/services/World_Terrain_Base/MapServer',
            World_Topo_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Topo_Map/MapServer')


for tile_name, tile_url in ESRI.items():
    tile_url += add
    folium.TileLayer(tile_url,
                    name=tile_name,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community').add_to(map_points)
    

folium.LayerControl().add_to(map_layers)

map_layers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_046281e8cdc8702e38a6873cc50cf892 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_046281e8cdc8702e38a6873cc50cf892&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_046281e8cdc8702e38a6873cc50cf892 = L.map(
#                 &quot;map_046281e8cdc8702e38a6873cc50cf892&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ee40acd9ac509e91bf7577e1a5e0546 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_046281e8cdc8702e38a6873cc50cf892);
#
#
#             var circle_cd740451ceaeec38a9e69cb6cba07f64 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_046281e8cdc8702e38a6873cc50cf892);
#
#
#         var popup_b66b981097669a70945dcb0a2db1881e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2cbf4888d4b30310e0001e428adcf540 = $(`&lt;div id=&quot;html_2cbf4888d4b30310e0001e428adcf540&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_b66b981097669a70945dcb0a2db1881e.setContent(html_2cbf4888d4b30310e0001e428adcf540);
#
#
#
#         circle_cd740451ceaeec38a9e69cb6cba07f64.bindPopup(popup_b66b981097669a70945dcb0a2db1881e)
#         ;
#
#
#
#
#             var circle_1b7ebb0d17e9280150047e5ef874f865 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_046281e8cdc8702e38a6873cc50cf892);
#
#
#         var popup_4593013c295cb177656b5b9271602f01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eec812fa8dd04516154b2895964f04fe = $(`&lt;div id=&quot;html_eec812fa8dd04516154b2895964f04fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_4593013c295cb177656b5b9271602f01.setContent(html_eec812fa8dd04516154b2895964f04fe);
#
#
#
#         circle_1b7ebb0d17e9280150047e5ef874f865.bindPopup(popup_4593013c295cb177656b5b9271602f01)
#         ;
#
#
#
#
#             var circle_d089bf5aaedea64b0ddff4b25886a84a = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_046281e8cdc8702e38a6873cc50cf892);
#
#
#         var popup_076e85e44843fd0a5af955e5fd01ef36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d21752d400d341144a648daba4379f5c = $(`&lt;div id=&quot;html_d21752d400d341144a648daba4379f5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_076e85e44843fd0a5af955e5fd01ef36.setContent(html_d21752d400d341144a648daba4379f5c);
#
#
#
#         circle_d089bf5aaedea64b0ddff4b25886a84a.bindPopup(popup_076e85e44843fd0a5af955e5fd01ef36)
#         ;
#
#
#
#
#             var circle_5ec66d12af143880be0b30a7796e2073 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru

# %%
# Creating Heatmap

from folium.plugins import HeatMap

# Create our point map object
map_heat = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius='15',
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_heat)
    
# convert to array format for our heatmap
suburbsArray = df_suburbs[['Latitude', 'Longitude']].values

# plot heatmap
map_heat.add_child(HeatMap(suburbsArray))

map_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_051d16a110c4e32b3cfddaeffa2e50b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_051d16a110c4e32b3cfddaeffa2e50b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_051d16a110c4e32b3cfddaeffa2e50b6 = L.map(
#                 &quot;map_051d16a110c4e32b3cfddaeffa2e50b6&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff5ef147d5d8e5b31743b11086f05405 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_051d16a110c4e32b3cfddaeffa2e50b6);
#
#
#             var circle_3c44728859297ea8a96862f2a4fae130 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_051d16a110c4e32b3cfddaeffa2e50b6);
#
#
#         var popup_5264e7a808eb17992a09bd7bfb8af07f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8cc769187e4baa9175a60f46d63523c = $(`&lt;div id=&quot;html_d8cc769187e4baa9175a60f46d63523c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_5264e7a808eb17992a09bd7bfb8af07f.setContent(html_d8cc769187e4baa9175a60f46d63523c);
#
#
#
#         circle_3c44728859297ea8a96862f2a4fae130.bindPopup(popup_5264e7a808eb17992a09bd7bfb8af07f)
#         ;
#
#
#
#
#             var circle_db06c1ab988a5360115550fb4fe4e452 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_051d16a110c4e32b3cfddaeffa2e50b6);
#
#
#         var popup_9dcc966206dced1e45c0105062cc7d0d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12d1527854a2852280b66a5f4830baeb = $(`&lt;div id=&quot;html_12d1527854a2852280b66a5f4830baeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_9dcc966206dced1e45c0105062cc7d0d.setContent(html_12d1527854a2852280b66a5f4830baeb);
#
#
#
#         circle_db06c1ab988a5360115550fb4fe4e452.bindPopup(popup_9dcc966206dced1e45c0105062cc7d0d)
#         ;
#
#
#
#
#             var circle_0a6164443396fd4284b93d2683c9bf49 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_051d16a110c4e32b3cfddaeffa2e50b6);
#
#
#         var popup_08779f30ead595c7b66e84ff4a1b4931 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24dff25e343f9b5dba085fbf8f413310 = $(`&lt;div id=&quot;html_24dff25e343f9b5dba085fbf8f413310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_08779f30ead595c7b66e84ff4a1b4931.setContent(html_24dff25e343f9b5dba085fbf8f413310);
#
#
#
#         circle_0a6164443396fd4284b93d2683c9bf49.bindPopup(popup_08779f30ead595c7b66e84ff4a1b4931)
#         ;
#
#
#
#
#             var circle_e5753766aa43d4d39a8ba9719a1962f0 = L.circle(
#                 [-33.920011, 18.642819],

# %%
# !pip install selenium

# %%
import os
import time
from selenium import webdriver
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/tl/q1c606q156xbmnyd03bvkf7r0000gn/T/ipykernel_28508/94547548.py in <module>
#       1 import os
#       2 import time
# ----> 3 from selenium import webdriver
#
# ModuleNotFoundError: No module named 'selenium'

# %%
delay = 5

heat = 'map_heat.html'
unemployment = 'map_unemployment.html'

def export_maps(map_file, map_image, map_obj):
    browser = webdriver.Chrome('C:\\Users\\Edwin\\Downloads\\chromedriver_win32\\chromedriver.exe')
    tmpUrl = 'file://{path}/{mapfile}'.format(path=os.getcwd(), mapfile=map_file)
    map_obj.save(map_file)
    browser.get(tmpUrl)
    time.sleep(delay)
    browser.save_screenshot(map_image)
    browser.quit()
    
export_maps(heat, 'map_heat.png', map_heat)

# %%
export_maps(unemployment, 'map_unemployment.png', map_unemployment)
